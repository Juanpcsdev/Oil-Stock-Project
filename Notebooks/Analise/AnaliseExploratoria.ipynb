# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

df1=pd.read_csv('../../camada_ouro/Join_dataframes_new_end.csv')

display(df1)
# Out:
#             Date             Datetime  Close_Real_EYAC2  Volume_EYAC2  \
# 0     2010-01-04  2010-01-04 16:56:00         37.937621   13303743.87
# 1     2010-01-05  2010-01-05 16:56:00         37.774220   21396519.48
# 2     2010-01-06  2010-01-06 16:56:00         38.805357   18720547.15
# 3     2010-01-07  2010-01-07 16:56:00         36.425929   10964646.19
# 4     2010-01-08  2010-01-08 16:56:00         35.037787   14624078.31
# ...          ...                  ...               ...           ...
# 3626  2024-12-20  2024-12-20 16:56:00         38.845595   59277431.74
# 3627  2024-12-23  2024-12-23 16:56:00         39.320157   43785532.81
# 3628  2024-12-26  2024-12-26 16:56:00         37.867609   22920777.53
# 3629  2024-12-27  2024-12-27 16:56:00         36.066818   24167282.36
# 3630  2024-12-30  2024-12-30 16:56:00         36.614223   22355586.67
#
#       Close_Dolar_EYAC2  Price_Dolar_Petro  Volume_Petro Change%_Petro  \
# ...

# %%
df1.describe()
# Out:
#        Close_Real_EYAC2  Volume_EYAC2  Close_Dolar_EYAC2  Price_Dolar_Petro  \
# count       3631.000000  3.631000e+03        3631.000000        3631.000000
# mean          22.663786  5.021059e+07           7.321450          71.585841
# std            8.357270  3.241166e+07           3.894951          20.982274
# min            2.741681  3.249219e+05           0.702617          17.600000
# 25%           16.502374  2.769504e+07           4.785132          53.140000
# 50%           22.549266  4.339195e+07           6.378014          72.260000
# 75%           28.353435  6.419743e+07           8.387037          88.745000
# max           44.940410  4.902302e+08          23.302318         119.780000
#
#        Volume_Petro  Índice_Ibovespa  Change%_Ibovespa
# count   3631.000000      3631.000000       3631.000000
# mean     276.436717     81473.978158          0.421258
# std      166.013704     27527.860810          8.946161
# min        1.000000     37497.470000        -46.815962
# ...

# %% [markdown]
# O menor valor da ação custa 0,70 dólares, enquanto o maior valor custa 23,30 dólares. Já o barril do petróleo custou no máximo 119,78 dólares e seu mínimo foi de 17,60 dólares

# %%
df1['Date']= pd.to_datetime(df1['Date'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3631 entries, 0 to 3630
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               3631 non-null   datetime64[ns]
#  1   Datetime           3631 non-null   object
#  2   Close_Real_EYAC2   3631 non-null   float64
#  3   Volume_EYAC2       3631 non-null   float64
#  4   Close_Dolar_EYAC2  3631 non-null   float64
#  5   Price_Dolar_Petro  3631 non-null   float64
#  6   Volume_Petro       3631 non-null   float64
#  7   Change%_Petro      3631 non-null   object
#  8   Índice_Ibovespa    3631 non-null   float64
#  9   Change%_Ibovespa   3631 non-null   float64
#  10  Value_IPCA         3631 non-null   object
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 312.2+ KB

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(data= df1, x='Date', y= 'Close_Real_EYAC2', color='#41afda', label='Real') #Real
sns.lineplot(data= df1, x='Date', y= 'Close_Dolar_EYAC2',color='#2c39a8', label='Dólar') #Dolar
plt.fill_between(df1['Date'], df1['Close_Real_EYAC2'], color='#41afda', alpha=1) #Real
plt.fill_between(df1['Date'], df1['Close_Dolar_EYAC2'], color='#2c39a8', alpha=1) #Dolar
plt.title('Variação diária entre a Ação em Real e Dólar')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.legend()
plt.show()

# %% [markdown]
# O dólar foi ficando mais caro com o passar do tempo e após 2016 ele sofreu uma estabilidade.
#  A ação estava valendo mais entre 2010 e 2014, e a partir de 2015 ele começa a descer e estabilizar.

# %%
#sns.lineplot(data= df1, x='Date', y= 'Close_Dolar_EYAC2',palette="tab10", linewidth=2.5)

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(data= df1, x='Date', y= 'Price_Dolar_Petro', color='#41afda')
plt.fill_between(df1['Date'], df1['Price_Dolar_Petro'], color='#41afda', alpha=0.5)
plt.title('Variação diária do preço do barril de petróleo')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# Percebesse que após a pandemia, o preço do barril do petróleo foi aumentando

# %%
df1.head()
# Out:
#         Date             Datetime  Close_Real_EYAC2  Volume_EYAC2  \
# 0 2010-01-04  2010-01-04 16:56:00         37.937621   13303743.87
# 1 2010-01-05  2010-01-05 16:56:00         37.774220   21396519.48
# 2 2010-01-06  2010-01-06 16:56:00         38.805357   18720547.15
# 3 2010-01-07  2010-01-07 16:56:00         36.425929   10964646.19
# 4 2010-01-08  2010-01-08 16:56:00         35.037787   14624078.31
#
#    Close_Dolar_EYAC2  Price_Dolar_Petro  Volume_Petro Change%_Petro  \
# 0          22.005581              81.51        263.54         2.71%
# 1          21.927335              81.77        258.89         0.32%
# 2          22.382971              83.18        370.06         1.72%
# 3          20.918813              82.66        246.63        -0.63%
# 4          20.148239              82.75        310.38         0.11%
#
#    Índice_Ibovespa  Change%_Ibovespa Value_IPCA
# 0         70045.08          0.399893      0.75%
# 1         70239.82         -3.775387      0.75%
# ...

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(data= df1, x='Date', y= 'Índice_Ibovespa',palette="tab10", linewidth=2.5)
sns.lineplot(data= df1, x='Date', y= 'Close_Real_EYAC2', color='#41afda', label='Real') #Real
#plt.fill_between(df1['Date'], df1['Índice_Ibovespa'], color='#41afda', alpha=0.5)
plt.title('Variação diária do Índice do Ibovespa')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.show()
# Out:
# C:\Users\YQ693MD\AppData\Local\Temp\ipykernel_11804\359080778.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data= df1, x='Date', y= 'Índice_Ibovespa',palette="tab10", linewidth=2.5)

# %% [markdown]
# Apartir de 2016

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(data= df1, x='Date', y= 'Price_Dolar_Petro', color='#B15E85',linewidth=1.5, label='Barril de Petróleo')
sns.lineplot(data= df1, x='Date', y= 'Close_Dolar_EYAC2',color='#212ea2', linewidth=1.5, label='Ação em Dólar') 
plt.fill_between(df1['Date'], df1['Price_Dolar_Petro'], color='#B15E85', alpha=0.7) 
plt.fill_between(df1['Date'], df1['Close_Dolar_EYAC2'], color='#212ea2', alpha=0.6) 
plt.title('Variação diária entre a ação dólar e o barril de petróleo')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.legend()
plt.show()

# %%
# # Supondo que df1 seja o seu DataFrame original
# # Transforme o DataFrame usando melt, excluindo o índice Ibovespa
# df_melted = df1.melt(id_vars=['Date'], value_vars=['Price_Dolar_Petro', 'Close_Dolar_EYAC2'], 
#                      var_name='Variable', value_name='Value')

# # Crie os subplots
# fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# # Primeiro gráfico: Price_Dolar_Petro
# sns.lineplot(data=df_melted[df_melted['Variable'] == 'Price_Dolar_Petro'], 
#              x='Date', y='Value', ax=axes[0], palette="tab10", linewidth=1)
# axes[0].set_title('Price Dolar Petro')

# # Segundo gráfico: Close_Dolar_EYAC2
# sns.lineplot(data=df_melted[df_melted['Variable'] == 'Close_Dolar_EYAC2'], 
#              x='Date', y='Value', ax=axes[1], palette="tab10", linewidth=1)
# axes[1].set_title('Close Dolar EYAC2')

# # Ajuste o layout
# plt.tight_layout()

# # Exibir os gráficos
# plt.show()

# %% [markdown]
# A partir

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['Close_Dolar_EYAC2'], stat='percent', bins=10)
plt.title('Distribuição percentual da ação em Dólar')
plt.xlabel('Valor')
plt.ylabel('Porcentagem')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['Price_Dolar_Petro'], stat='percent', bins=10)
plt.title('Distribuição percentual do barril de petróleo')
plt.xlabel('Valor')
plt.ylabel('Porcentagem')
plt.show()

# %% [markdown]
# O preço do barril do petróleo é mais volátil que o preço das ações

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['Close_Dolar_EYAC2'])
plt.title('Distribuição da ação em Dólar')
plt.xlabel('Valor')
plt.ylabel('Contagem')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['Price_Dolar_Petro'])
plt.title('Distribuição do barril de petróleo')
plt.xlabel('Valor')
plt.ylabel('Contagem')
plt.show()

# %% [markdown]
# O valor do petróleo tem uam maior variabilidade do que o preçõ da ação

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['Índice_Ibovespa'])
plt.title('Distribuição do Índice do Ibovespa')
plt.xlabel('Valor')
plt.ylabel('Contagem')
plt.show()

# %% [markdown]
# 1. Influência Direta: Ações Ligadas ao Setor de Petróleo
# • O Ibovespa é composto por várias empresas, e Petrobras (PETR3, PETR4) tem um peso enorme no índice.
# • Como a Petrobras é uma petroleira, o preço do barril de petróleo influencia diretamente seu lucro.
# • Alta no petróleo → tende a aumentar lucro da Petrobras → ações sobem → Ibovespa sobe.
# • Queda no petróleo → pode reduzir lucro → ações caem → impacto negativo no Ibovespa.
# ⸻
# 2. Relação com o Câmbio
# • O petróleo é cotado em dólar, e o Brasil é um exportador de petróleo.
# • Quando o petróleo sobe, pode haver:
# • Entrada de dólares no Brasil (via exportações)
# • Valorização do real (ou menor pressão de desvalorização)
# • Isso pode impactar positivamente o Ibovespa, especialmente empresas que se beneficiam de dólar mais baixo (como varejo e consumo interno).
# ⸻
# 3. Impacto na Inflação e Juros
# • O petróleo afeta o custo dos combustíveis (gasolina, diesel), que influenciam o IPCA (inflação).
# • Alta no petróleo → aumento da inflação → pode levar o Banco Central a subir juros → impacto negativo no Ibovespa.
# • Então, o petróleo também afeta o ciclo de política monetária indiretamente.
# ⸻
# 4. Relação Global e Sentimento de Mercado
# • Alta no petróleo pode sinalizar crescimento global (mais demanda por energia) → otimismo → bolsas sobem.
# • Mas se a alta for por choques de oferta (ex: guerra, crise na OPEP), pode gerar temor de inflação global → bolsas caem.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(df1['Close_Dolar_EYAC2'])
plt.title('Boxplot da ação em Dólar')
plt.ylabel('Distribuição')
plt.show()

# %% [markdown]
# O preço da ação apresenta outliers

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(df1['Close_Real_EYAC2'])
plt.title('Boxplot da ação em Real')
plt.ylabel('Distribuição')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(df1['Price_Dolar_Petro'])
plt.title('Boxplot do barril de petróleo')
plt.ylabel('Distribuição')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(df1['Índice_Ibovespa'])
plt.title('Boxplot do Índice do Ibovespa')
plt.ylabel('Distribuição')
plt.show()

# %%
df_retorno = df1.copy()
df_retorno['retorno_diario'] = df_retorno['Close_Dolar_EYAC2'].pct_change() * 100

#Gráfico de linha
plt.figure(figsize=(10, 4))
plt.plot(df_retorno['Date'], df_retorno['retorno_diario'])
plt.title('Variação Percentual Diária')
plt.xlabel('Data')
plt.ylabel('% Retorno')
plt.grid(True)
plt.show()

#Histograma com KDE
sns.histplot(df_retorno['retorno_diario'].dropna(), kde=True, bins=30)
plt.title('Distribuição dos Retornos Diários (%)')
plt.xlabel('% Retorno')
plt.show()

# %%
df_retorno2 = df1.copy()

df_retorno2['retorno_diario'] = df_retorno2['Price_Dolar_Petro'].pct_change() * 100

#Gráfico de linha
plt.figure(figsize=(10, 4))
plt.plot(df_retorno2['Date'], df_retorno2['retorno_diario'])
plt.title('Variação Percentual Diária')
plt.xlabel('Data')
plt.ylabel('% Retorno')
plt.grid(True)
plt.show()

#Histograma com KDE
sns.histplot(df_retorno2['retorno_diario'].dropna(), kde=True, bins=30)
plt.title('Distribuição dos Retornos Diários (%)')
plt.xlabel('% Retorno')
plt.show()

# %% [markdown]
# ##### Correlação Barril de Petróleo e Ação em Dólar

# %%
df1[['Price_Dolar_Petro', 'Close_Dolar_EYAC2']].corr(method='pearson')
# Out:
#                    Price_Dolar_Petro  Close_Dolar_EYAC2
# Price_Dolar_Petro           1.000000           0.583167
# Close_Dolar_EYAC2           0.583167           1.000000

# %%
plt.figure(figsize=(10, 6))
x = df1['Price_Dolar_Petro']
y = df1['Close_Dolar_EYAC2']
plt.scatter(x, y)
plt.title('Correlação entre os preços do barril de petróleo e a ação em Dólar')
plt.xlabel('Preço Barril')
plt.ylabel('Preço Ação')

#Linha de tendência
z = np.polyfit(x,y,1)
p = np.polyval(z, x)
plt.plot(x, p, color='red')

plt.show()

# %% [markdown]
# A correlação do preço do barril do petróleo e ação estão diretamento proporcionais, quando o preço do barril do petróleo aumenta a da ação também irá aumentar

# %%
df1[["Close_Real_EYAC2","Índice_Ibovespa"]].corr(method="pearson")
# Out:
#                   Close_Real_EYAC2  Índice_Ibovespa
# Close_Real_EYAC2          1.000000         0.784098
# Índice_Ibovespa           0.784098         1.000000

# %%
plt.figure(figsize=(10, 6))
x = df1['Índice_Ibovespa']
y = df1['Close_Real_EYAC2']
plt.scatter(x, y)
plt.title('Correlação entre o índice do Ibovespa e Ação em Real')
plt.xlabel('Ibovespa')
plt.ylabel('Ação')

#Linha de tendência
z = np.polyfit(x,y,1)
p = np.polyval(z, x)
plt.plot(x, p, color='red')

plt.show()

# %% [markdown]
# # Análise Mensal

# %%
#Criação de uma coluna ano/mes
df1['ano_mes'] = df1['Date'].dt.to_period('M')

# %%
df1.head(2)
# Out:
#         Date             Datetime  Close_Real_EYAC2  Volume_EYAC2  \
# 0 2010-01-04  2010-01-04 16:56:00         37.937621   13303743.87
# 1 2010-01-05  2010-01-05 16:56:00         37.774220   21396519.48
#
#    Close_Dolar_EYAC2  Price_Dolar_Petro  Volume_Petro Change%_Petro  \
# 0          22.005581              81.51        263.54         2.71%
# 1          21.927335              81.77        258.89         0.32%
#
#    Índice_Ibovespa  Change%_Ibovespa Value_IPCA  ano_mes
# 0         70045.08          0.399893      0.75%  2010-01
# 1         70239.82         -3.775387      0.75%  2010-01

# %%
#Selecionando apenas os valores de fechamentos mensais

colunas_media = ['Close_Real_EYAC2','Close_Dolar_EYAC2','Volume_EYAC2','Price_Dolar_Petro','Volume_Petro','Índice_Ibovespa','ano_mes']

list_dates = []

#Adicionando valores do fechamento (último dia) de cada mês
for x in range (2010,2025):
    for y in range (1,13):
        list_dates.append(list(df1[(df1['Date'].dt.year==x) & (df1['Date'].dt.month == y)].iloc[-1]))

#Transformando em dataframe com colunas selecionadas
df_mean = pd.DataFrame(list_dates, columns=df1.columns)
df_mean = df_mean[colunas_media]

# %%
#União da tabela de fechamento com os valores de Inflação mensais
df_mean = df_mean.merge(df1[['ano_mes','Value_IPCA']].drop_duplicates(),right_on='ano_mes', left_on='ano_mes',how='left')

# %%
df_mean.tail(2)
# Out:
#      Close_Real_EYAC2  Close_Dolar_EYAC2  Volume_EYAC2  Price_Dolar_Petro  \
# 178         38.699903           7.111861   44011586.42              67.72
# 179         36.614223           6.605965   22355586.67              70.53
#
#      Volume_Petro  Índice_Ibovespa  ano_mes Value_IPCA
# 178        106.39        125667.83  2024-11      0.39%
# 179         93.10        120283.40  2024-12      0.52%

# %%
# df_mean['Change%_Petro'] = df_mean['Price_Dolar_Petro'].pct_change() * 100
# df_mean['Change%_Ibovespa'] = df_mean['Índice_Ibovespa'].pct_change() * 100

# %%
#Valor da inflação como tipo float
df_mean['Inflac_IPCA'] = df_mean['Value_IPCA'].replace({'%':''},regex=True).astype(float)

# %%
#Adicionando coluna de inflação acumulada em 12 meses

lista_ipca = []

for i in df_mean.index:
    taxas_inflacao = [x for x in df_mean['Inflac_IPCA'].iloc[max(0, i-12):i] / 100]
    #Calculando a inflação acumulada
    inflacao_acumulada = 1
    for taxa in taxas_inflacao:
        inflacao_acumulada *= (1 + taxa)

    inflacao_acumulada -= 1
    inflacao_acumulada = inflacao_acumulada * 100  #Convertendo para porcentagem
    lista_ipca.append(inflacao_acumulada)

df_mean['IPCA_Acumulado'] = lista_ipca

# %%
#Transformando coluna ano/mes em timestamp
df_mean['Date'] = df_mean['ano_mes'].dt.to_timestamp()

# %% [markdown]
# ### Correlação de Pearson

# %%
df_mean.loc[:, df_mean.columns.difference(['Value_IPCA', 'ano_mes'])].corr(method='pearson')
# Out:
#                    Close_Dolar_EYAC2  Close_Real_EYAC2      Date  \
# Close_Dolar_EYAC2           1.000000          0.416398 -0.599116
# Close_Real_EYAC2            0.416398          1.000000  0.458312
# Date                       -0.599116          0.458312  1.000000
# IPCA_Acumulado             -0.315999         -0.278918  0.021058
# Inflac_IPCA                -0.061582         -0.116968 -0.084649
# Price_Dolar_Petro           0.590178          0.334877 -0.300372
# Volume_EYAC2               -0.408844          0.094457  0.489724
# Volume_Petro                0.077440         -0.467907 -0.493074
# Índice_Ibovespa            -0.169058          0.784836  0.858894
#
#                    IPCA_Acumulado  Inflac_IPCA  Price_Dolar_Petro  \
# Close_Dolar_EYAC2       -0.315999    -0.061582           0.590178
# Close_Real_EYAC2        -0.278918    -0.116968           0.334877
# Date                     0.021058    -0.084649          -0.300372
# ...

# %% [markdown]
# ##### Valor da ação em Real

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(df_mean['Close_Real_EYAC2'], ax=axes[0])
axes[0].set_title('Histograma')
axes[0].set_xlabel('Distribuição da ação')
axes[0].set_ylabel('Contagem')

sns.boxplot(df_mean['Close_Real_EYAC2'], ax=axes[1])
axes[1].set_title('Boxplot')
axes[1].set_ylabel('Distribuição')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Valor da ação em Dólar

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(df_mean['Close_Dolar_EYAC2'], ax=axes[0])
axes[0].set_title('Histograma')
axes[0].set_xlabel('Distribuição da ação')
axes[0].set_ylabel('Contagem')

sns.boxplot(df_mean['Close_Dolar_EYAC2'], ax=axes[1])
axes[1].set_title('Boxplot')
axes[1].set_ylabel('Distribuição')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Valor do barril do petróleo

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(df_mean['Price_Dolar_Petro'], ax=axes[0])
axes[0].set_title('Histograma')
axes[0].set_xlabel('Distribuição do barril de petróleo')
axes[0].set_ylabel('Contagem')

sns.boxplot(df_mean['Price_Dolar_Petro'], ax=axes[1])
axes[1].set_title('Boxplot')
axes[1].set_ylabel('Distribuição')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Linha do Tempo: Ação em dólar X Barril do Petróleo

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.lineplot(x=df_mean['Date'],y=df_mean['Close_Dolar_EYAC2'], ax=axes[0])
axes[0].set_title('Variação mensal da ação em dólar ')
axes[0].set_xlabel('Ano-mês')
axes[0].set_ylabel('Valor')


sns.lineplot(x=df_mean['Date'],y=df_mean['Price_Dolar_Petro'], ax=axes[1], color='purple')
axes[1].set_title('Variação mensal do barril de petróleo')
axes[1].set_xlabel('Ano-mês')
axes[1].set_ylabel('Valor')


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))

sns.lineplot(x=df_mean['Date'],y=df_mean['Price_Dolar_Petro'], label='Barril de Petróleo', color='purple')
sns.lineplot(x=df_mean['Date'],y=df_mean['Close_Dolar_EYAC2'], label='Ação em Dólar')

plt.ylabel('Preço')
plt.xlabel('Ano-mês')
plt.legend()
plt.show()

# %% [markdown]
# #### Correlações

# %% [markdown]
# ##### Ibovespa X Ação em Real

# %%
plt.figure(figsize=(10, 6))
x = df_mean['Índice_Ibovespa']
y = df_mean['Close_Real_EYAC2']
plt.scatter(x, y)
plt.title('Correlação entre o índice do Ibovespa e a ação em Real')
plt.xlabel('Ibovespa')
plt.ylabel('Ação em Real')

#Linha de tendência
z = np.polyfit(x,y,1)
p = np.polyval(z, x)
plt.plot(x, p, color='red')

plt.show()

# %% [markdown]
# ##### Barril do Petróleo X Ação em Dólar

# %%
plt.figure(figsize=(10, 6))
x = df_mean['Price_Dolar_Petro']
y = df_mean['Close_Dolar_EYAC2']
plt.scatter(x, y)
plt.title('Correlação entre os preços do barril de petróleo e a ação em Dólar')
plt.xlabel('Barril de Petróleo')
plt.ylabel('Ação em Dólar')

#Linha de tendência
z = np.polyfit(x,y,1)
p = np.polyval(z, x)
plt.plot(x, p, color='red')

plt.show()

# %% [markdown]
# ##### Variação Acumulada

# %%
df_return = df_mean[['Date','Índice_Ibovespa','Close_Real_EYAC2','Inflac_IPCA']].copy()
df_return['Ibovespa_return'] = df_return['Índice_Ibovespa'].pct_change() * 100
df_return['real_return'] = df_return['Close_Real_EYAC2'].pct_change() * 100

df_return['Ibovespa_return'] = (1 + df_return['Ibovespa_return'] / 100).cumprod() - 1
df_return['real_return'] = (1 + df_return['real_return'] / 100).cumprod() - 1

# %%
#Criando um gráfico para comparação
plt.figure(figsize=(14, 7))
plt.plot(df_return['Date'], df_return['Ibovespa_return'], label='Índice do Ibovespa', color='blue')
plt.plot(df_return['Date'], df_return['Inflac_IPCA'], label='Inflação (IPCA)', color='red')
plt.plot(df_return['Date'], df_return['real_return'], label='Ação EYAC2', color='yellow')
plt.title('Comparação entre as variações do Ibovespa, IPCA e a ação acumulados')
plt.xlabel('Ano-mês')
plt.ylabel('Percentual')
plt.legend()
plt.grid()
plt.show()

# %%
df_mean.tail(18)
# Out:
#      Close_Real_EYAC2  Close_Dolar_EYAC2  Volume_EYAC2  Price_Dolar_Petro  \
# 162         30.339032           5.786358   91290854.25              81.32
# 163         31.224936           5.932690   48971525.87              82.96
# 164         32.368186           6.397507   40227735.72              88.80
# 165         33.789306           6.829710   36964901.24              80.50
# 166         33.551194           7.026428   58808623.62              76.05
# 167         35.480674           7.391807   21421893.14              71.97
# 168         38.632532           7.769393   57978963.89              75.71
# 169         39.908712           8.196659   61899958.42              77.45
# 170         35.277860           6.969430   31958472.56              82.42
# 171         41.926207           8.582818   36635262.71              81.28
# 172         37.862392           7.664607   53929665.53              76.73
# 173         39.759413           8.057272   22019610.17              80.64
# ...

# %%
#Criando um gráfico para comparação
plt.figure(figsize=(20, 7))
plt.plot(df_mean['Date'], df_mean['Close_Real_EYAC2'].pct_change() * 100, label='Ação EYAC2', color='#90bce6')
plt.plot(df_mean['Date'], df_mean['Índice_Ibovespa'].pct_change() * 100, label='Índice de Fechamento do Ibovespa', color='blue')
plt.plot(df_mean['Date'], df_mean['IPCA_Acumulado'], label='Inflação Acumulada (IPCA)', color='red')

plt.title('Variação mensal entre o Índice do Ibovespa, IPCA e ação de petróleo')
plt.xlabel('Data')
plt.ylabel('Percentual')
plt.legend()
plt.grid()
plt.show()

# %%
# Exemplo de valores percentuais anuais
variacao_ibovespa = df_mean['Índice_Ibovespa'].pct_change() # Variação percentual do Ibovespa
inflacao_ipca = df_mean['IPCA_Acumulado']       # Inflação IPCA
variacao_acao = df_mean['Close_Real_EYAC2'].pct_change()      # Variação percentual da sua ação

# Cálculo da taxa de juros real do Ibovespa e da ação
df_mean['taxa_real_ibovespa'] = ((1 + variacao_ibovespa) / (1 + inflacao_ipca / 100) - 1)
df_mean['taxa_real_acao'] = ((1 + variacao_acao) / (1 + inflacao_ipca / 100) - 1)

# %%
#Criando um gráfico para comparação
plt.figure(figsize=(14, 7))
plt.plot(df_mean['Date'], df_mean['taxa_real_acao'] * 100, label='Rentabilidade Acumulada do IPCA', color='yellow')
plt.plot(df_mean['Date'], df_mean['taxa_real_ibovespa'] * 100, label='Rentabilidade Acumulada do Ibovespa', color='blue')

plt.title('Variação mensal entre o Índice do Ibovespa e a ação de petróleo')
plt.xlabel('Data')
plt.ylabel('Percentual')
plt.legend()
plt.grid()
plt.show()

# %%
teste = df1.copy()

# %%
teste.head()
# Out:
#         Date             Datetime  Close_Real_EYAC2  Volume_EYAC2  \
# 0 2010-01-04  2010-01-04 16:56:00         37.937621   13303743.87
# 1 2010-01-05  2010-01-05 16:56:00         37.774220   21396519.48
# 2 2010-01-06  2010-01-06 16:56:00         38.805357   18720547.15
# 3 2010-01-07  2010-01-07 16:56:00         36.425929   10964646.19
# 4 2010-01-08  2010-01-08 16:56:00         35.037787   14624078.31
#
#    Close_Dolar_EYAC2  Price_Dolar_Petro  Volume_Petro Change%_Petro  \
# 0          22.005581              81.51        263.54         2.71%
# 1          21.927335              81.77        258.89         0.32%
# 2          22.382971              83.18        370.06         1.72%
# 3          20.918813              82.66        246.63        -0.63%
# 4          20.148239              82.75        310.38         0.11%
#
#    Índice_Ibovespa  Change%_Ibovespa Value_IPCA  ano_mes
# 0         70045.08          0.399893      0.75%  2010-01
# ...

# %%
teste['IPCA_Acumulado']=teste['Value_IPCA'].replace({"%":" "},regex=True).astype(float)

# %%
teste['Change%_Ibovespa']=teste['Índice_Ibovespa'].pct_change() * 100
teste['Change%_EYAC2']=teste['Close_Real_EYAC2'].pct_change() * 100

# %%
#Criando um gráfico para comparação
plt.figure(figsize=(20, 7))
#plt.plot(teste['Date'], teste['Change%_EYAC2'], label='Ação EYAC2', color='#90bce6')
plt.plot(teste['Date'], teste['Change%_Ibovespa'], label='Índice de Fechamento do Ibovespa', color='blue')
plt.plot(teste['Date'], teste['IPCA_Acumulado'], label='Inflação Acumulada (IPCA)', color='red')

plt.title('Valorização diária entre o Índice do Ibovespa, IPCA e ação de petróleo')
plt.xlabel('Data')
plt.ylabel('Percentual')
plt.legend()
plt.grid()
plt.show()

# %%
teste.head()
# Out:
#         Date             Datetime  Close_Real_EYAC2  Volume_EYAC2  \
# 0 2010-01-04  2010-01-04 16:56:00         37.937621   13303743.87
# 1 2010-01-05  2010-01-05 16:56:00         37.774220   21396519.48
# 2 2010-01-06  2010-01-06 16:56:00         38.805357   18720547.15
# 3 2010-01-07  2010-01-07 16:56:00         36.425929   10964646.19
# 4 2010-01-08  2010-01-08 16:56:00         35.037787   14624078.31
#
#    Close_Dolar_EYAC2  Price_Dolar_Petro  Volume_Petro Change%_Petro  \
# 0          22.005581              81.51        263.54         2.71%
# 1          21.927335              81.77        258.89         0.32%
# 2          22.382971              83.18        370.06         1.72%
# 3          20.918813              82.66        246.63        -0.63%
# 4          20.148239              82.75        310.38         0.11%
#
#    Índice_Ibovespa  Change%_Ibovespa Value_IPCA  ano_mes  IPCA_Acumulado  \
# 0         70045.08               NaN      0.75%  2010-01            0.75
# ...

# %%
df_teste = df_mean.copy()

# %%
df_teste['Normalized_EYAC2'] = df_teste['Close_Real_EYAC2'] / df_teste['Close_Real_EYAC2'].iloc[0]
df_teste['Normalized_Ibovespa'] = df_teste['Índice_Ibovespa'] / df_teste['Índice_Ibovespa'].iloc[0]

# %%
df_teste['Retorno_EYAC2'] = df_teste['Close_Real_EYAC2'].pct_change()
df_teste['Retorno_Ibovespa'] = df_teste['Índice_Ibovespa'].pct_change()

# %%
# Gráfico de Normalização
plt.figure(figsize=(14, 7))
plt.plot(df_teste['Date'], df_teste['Normalized_EYAC2'], label='Close_Real_EYAC2 Normalizado', color='blue')
plt.plot(df_teste['Date'], df_teste['Normalized_Ibovespa'], label='Índice Ibovespa Normalizado', color='red')
plt.title('Comparação Normalizada entre Close_Real_EYAC2 e Índice Ibovespa')
plt.xlabel('Date')
plt.ylabel('Valor Normalizado')
plt.legend()
plt.grid()
plt.show()

# Gráfico de Retornos
plt.figure(figsize=(14, 7))
plt.plot(df_teste['Date'], df_teste['Retorno_EYAC2'], label='Retorno Close_Real_EYAC2', color='blue')
plt.plot(df_teste['Date'], df_teste['Retorno_Ibovespa'], label='Retorno Índice Ibovespa', color='red')
plt.title('Comparação de Retornos entre Close_Real_EYAC2 e Índice Ibovespa')
plt.xlabel('Date')
plt.ylabel('Retorno Percentual')
plt.legend()
plt.grid()
plt.show()

# %%
df_mean.tail()
# Out:
#      Close_Real_EYAC2  Close_Dolar_EYAC2  Volume_EYAC2  Price_Dolar_Petro  \
# 175         36.640116           7.343150   84437156.59              72.65
# 176         36.946330           7.156535   21146409.59              67.77
# 177         34.453725           6.663648   25596765.78              68.81
# 178         38.699903           7.111861   44011586.42              67.72
# 179         36.614223           6.605965   22355586.67              70.53
#
#      Volume_Petro  Índice_Ibovespa  ano_mes Value_IPCA  Inflac_IPCA  \
# 175        210.33        136004.01  2024-08     -0.02%        -0.02
# 176        189.29        131816.44  2024-09      0.44%         0.44
# 177        109.20        129713.33  2024-10      0.56%         0.56
# 178        106.39        125667.83  2024-11      0.39%         0.39
# 179         93.10        120283.40  2024-12      0.52%         0.52
#
#      IPCA_Acumulado       Date  taxa_real_ibovespa  taxa_real_acao
# ...

# %%
df_ibov = pd.read_csv('../../camada_prata/ibovespa_clean.csv')

# %%
df_ibov = df_ibov.sort_values('Date')

# %%
df_ibov.head(5)
# Out:
#           Date  Dia      Mês   Ano     Valor  Change % Year-Month
# 23  2010-01-04    4  January  2010  70045.08  0.399893     2010-1
# 31  2010-01-05    5  January  2010  70239.82 -3.775387     2010-1
# 40  2010-01-06    6  January  2010  70729.34 -2.585496     2010-1
# 48  2010-01-07    7  January  2010  70451.12  1.293007     2010-1
# 55  2010-01-08    8  January  2010  70262.70  1.334138     2010-1

# %%
df_ibov['Date'] = pd.to_datetime(df_ibov['Date'])

# %%
df_ibov[(df_ibov['Date'].dt.year == 2024) & (df_ibov['Date'].dt.month == 3)]
# Out:
#            Date  Dia    Mês   Ano      Valor  Change % Year-Month
# 3467 2024-03-01    1  March  2024  129180.37  0.544322     2024-3
# 3491 2024-03-04    4  March  2024  128340.54 -2.198781     2024-3
# 3501 2024-03-05    5  March  2024  128098.11  0.395490     2024-3
# 3510 2024-03-06    6  March  2024  128890.23 -1.170160     2024-3
# 3518 2024-03-07    7  March  2024  128339.76 -1.239047     2024-3
# 3526 2024-03-08    8  March  2024  127070.79 -0.893899     2024-3
# 3551 2024-03-11   11  March  2024  126123.56 -3.463631     2024-3
# 3560 2024-03-12   12  March  2024  127667.84 -2.534460     2024-3
# 3568 2024-03-13   13  March  2024  128006.05  1.558081     2024-3
# 3576 2024-03-14   14  March  2024  127689.97  0.528806     2024-3
# 3584 2024-03-15   15  March  2024  126741.81 -0.831209     2024-3
# 3608 2024-03-18   18  March  2024  126954.18 -0.283987     2024-3
# 3618 2024-03-19   19  March  2024  127528.85 -1.167808     2024-3
# ...

# %%
df_ibov['Date'].dt.is_month_end
# Out:
# 23      False
# 31      False
# 40      False
# 48      False
# 55      False
#         ...
# 3632    False
# 3657    False
# 3682    False
# 3690    False
# 3712    False
# Name: Date, Length: 3717, dtype: bool

# %%
list_dates = []

for x in range (2010,2025):
    for y in range (1,13):
        list_dates.append(list(df1[(df1['Date'].dt.year==x) & (df1['Date'].dt.month == y)].iloc[-1]))

df_teste = pd.DataFrame(list_dates, columns=df1.columns)

# %%
#Criando um gráfico para comparação
plt.figure(figsize=(14, 7))
sns.barplot(x=df_mean['Date'],y=df_mean['Índice_Ibovespa'].pct_change()*100, label='Ibovespa')
sns.barplot(x=df_mean['Date'], y=df_mean['Close_Real_EYAC2'].pct_change() * 100, label='açao em real')
sns.barplot(x=df_mean['Date'], y=df_mean['IPCA_Acumulado'], label='Inflação Acumulada (IPCA)', color='red')

plt.title('Comparação entre o Índice do Ibovespa e a Inflação (IPCA)')
plt.xlabel('Data')
plt.ylabel('Percentual')
plt.legend()
plt.grid()
plt.show()

# %%
(df1['Índice_Ibovespa'].cumsum()) * 100
# Out:
# 0       7.004508e+06
# 1       1.402849e+07
# 2       2.110142e+07
# 3       2.814654e+07
# 4       3.517281e+07
#             ...
# 3626    2.953496e+10
# 3627    2.954704e+10
# 3628    2.955915e+10
# 3629    2.957117e+10
# 3630    2.958320e+10
# Name: Índice_Ibovespa, Length: 3631, dtype: float64

# %%
df_teste = df_mean.copy()

# %%
df_teste['retorno_ibovespa'] = df_teste['Índice_Ibovespa'].pct_change()

# %%
df_teste['retorno_real'] = (1 + df_teste['retorno_ibovespa']) / (1 + df_teste['IPCA_Acumulado'] / 100) - 1

# %%
plt.figure(figsize=(14, 7))
plt.plot(df_teste['Date'], df_teste['retorno_real'], label='Retorno Real do Ibovespa', color='blue')
plt.plot(df_teste['Date'], df_teste['IPCA_Acumulado'] / 100, label='Inflação (IPCA)', color='red')
plt.title('Comparação entre Retorno Real do Ibovespa e Inflação')
plt.xlabel('Data')
plt.ylabel('Retorno / Inflação')
plt.legend()
plt.show()

# %%
media_retorno_real = df_teste['retorno_real'].mean()
media_inflacao = df_teste['IPCA_Acumulado'].mean() / 100  # Convertendo para decimal

print(f'Média do Retorno Real do Ibovespa: {media_retorno_real:.2%}')
print(f'Média da Inflação (IPCA): {media_inflacao:.2%}')
# Out:
# Média do Retorno Real do Ibovespa: -4.88%
# Média da Inflação (IPCA): 5.72%

# %%
df_combined = df_mean.copy()

# Calcular retornos percentuais
df_combined['Retorno_EYAC2'] = df_combined['Close_Real_EYAC2'].pct_change()
df_combined['Retorno_Ibovespa'] = df_combined['Índice_Ibovespa'].pct_change()

# Calcular inflação acumulada em decimal
df_combined['IPCA_Acumulado'] = df_combined['IPCA_Acumulado'] / 100

# Calcular retornos reais
df_combined['Retorno_Real_EYAC2'] = (1 + df_combined['Retorno_EYAC2']) / (1 + df_combined['IPCA_Acumulado']) - 1
df_combined['Retorno_Real_Ibovespa'] = (1 + df_combined['Retorno_Ibovespa']) / (1 + df_combined['IPCA_Acumulado']) - 1

# Calcular a volatilidade (desvio padrão dos retornos)
volatilidade_eyac2 = df_combined['Retorno_Real_EYAC2'].std()
volatilidade_ibovespa = df_combined['Retorno_Real_Ibovespa'].std()

# Criar o gráfico de dispersão
plt.figure(figsize=(10, 6))
plt.scatter(df_combined['Retorno_Real_Ibovespa'], df_combined['Retorno_Real_EYAC2'], color='blue', alpha=0.7)

# Adicionar título e rótulos
plt.title('Análise de Risco e Retorno: EYAC2 vs Ibovespa')
plt.xlabel('Retorno Real Ibovespa')
plt.ylabel('Retorno Real EYAC2')

# Adicionar linhas de referência para a volatilidade
plt.axhline(y=0, color='gray', linestyle='--')
plt.axvline(x=0, color='gray', linestyle='--')

# Adicionar anotações de volatilidade
plt.text(0.01, volatilidade_eyac2, f'Volatilidade EYAC2: {volatilidade_eyac2:.2%}', color='blue')
plt.text(0.01, -volatilidade_eyac2, f'Volatilidade EYAC2: {-volatilidade_eyac2:.2%}', color='blue')

plt.grid()
plt.show()

# %%
df_combined = df_mean.copy()

# Calcular retornos percentuais
df_combined['Retorno_EYAC2'] = df_combined['Close_Real_EYAC2'].pct_change()
df_combined['Retorno_Ibovespa'] = df_combined['Índice_Ibovespa'].pct_change()

# Calcular inflação acumulada em decimal
df_combined['IPCA_Acumulado'] = df_combined['IPCA_Acumulado'] / 100

# Calcular retornos reais
df_combined['Retorno_Real_EYAC2'] = (1 + df_combined['Retorno_EYAC2']) / (1 + df_combined['IPCA_Acumulado']) - 1
df_combined['Retorno_Real_Ibovespa'] = (1 + df_combined['Retorno_Ibovespa']) / (1 + df_combined['IPCA_Acumulado']) - 1

# Criar o gráfico de linhas para retornos reais
plt.figure(figsize=(14, 7))
plt.plot(df_combined['Date'], df_combined['Retorno_Real_EYAC2'], label='Retorno Real EYAC2', color='blue', marker='o')
plt.plot(df_combined['Date'], df_combined['Retorno_Real_Ibovespa'], label='Retorno Real Ibovespa', color='red', marker='o')

# Adicionar título e rótulos
plt.title('Comparação de Retornos Reais entre Close_Real_EYAC2 e Índice Ibovespa')
plt.xlabel('Data')
plt.ylabel('Retorno Real Percentual')
plt.axhline(0, color='gray', linestyle='--')  # Linha horizontal em y=0
plt.legend()
plt.grid()
plt.show()

# %%
df_combined.tail()
# Out:
#      Close_Real_EYAC2  Close_Dolar_EYAC2  Volume_EYAC2  Price_Dolar_Petro  \
# 175         36.640116           7.343150   84437156.59              72.65
# 176         36.946330           7.156535   21146409.59              67.77
# 177         34.453725           6.663648   25596765.78              68.81
# 178         38.699903           7.111861   44011586.42              67.72
# 179         36.614223           6.605965   22355586.67              70.53
#
#      Volume_Petro  Índice_Ibovespa  ano_mes Value_IPCA  Inflac_IPCA  \
# 175        210.33        136004.01  2024-08     -0.02%        -0.02
# 176        189.29        131816.44  2024-09      0.44%         0.44
# 177        109.20        129713.33  2024-10      0.56%         0.56
# 178        106.39        125667.83  2024-11      0.39%         0.39
# 179         93.10        120283.40  2024-12      0.52%         0.52
#
#      IPCA_Acumulado       Date  taxa_real_ibovespa  taxa_real_acao  \
# ...

# %%
df_mean.tail()
# Out:
#      Close_Real_EYAC2  Close_Dolar_EYAC2  Volume_EYAC2  Price_Dolar_Petro  \
# 175         36.640116           7.343150   84437156.59              72.65
# 176         36.946330           7.156535   21146409.59              67.77
# 177         34.453725           6.663648   25596765.78              68.81
# 178         38.699903           7.111861   44011586.42              67.72
# 179         36.614223           6.605965   22355586.67              70.53
#
#      Volume_Petro  Índice_Ibovespa  ano_mes Value_IPCA  Inflac_IPCA  \
# 175        210.33        136004.01  2024-08     -0.02%        -0.02
# 176        189.29        131816.44  2024-09      0.44%         0.44
# 177        109.20        129713.33  2024-10      0.56%         0.56
# 178        106.39        125667.83  2024-11      0.39%         0.39
# 179         93.10        120283.40  2024-12      0.52%         0.52
#
#      IPCA_Acumulado       Date  taxa_real_ibovespa  taxa_real_acao
# ...

# %%
df_combined = df_mean.copy()

# Calcular retornos percentuais
df_combined['Retorno_EYAC2'] = df_combined['Close_Real_EYAC2'].pct_change()
df_combined['Retorno_Ibovespa'] = df_combined['Índice_Ibovespa'].pct_change()

# Calcular inflação acumulada em decimal
df_combined['IPCA_Acumulado'] = df_combined['IPCA_Acumulado'] / 100

# Calcular retornos reais
df_combined['Retorno_Real_EYAC2'] = (1 + df_combined['Retorno_EYAC2']) / (1 + df_combined['IPCA_Acumulado']) - 1
df_combined['Retorno_Real_Ibovespa'] = (1 + df_combined['Retorno_Ibovespa']) / (1 + df_combined['IPCA_Acumulado']) - 1

# Criar um DataFrame para o gráfico de área
area_data = df_combined[['Date', 'Close_Real_EYAC2', 'Índice_Ibovespa']].copy()
area_data.set_index('Date', inplace=True)

# Criar o gráfico de área
plt.figure(figsize=(14, 7))
area_data.plot.area(alpha=0.5)

# Adicionar título e rótulos
plt.title('Composição de Retornos Reais: EYAC2 e Índice Ibovespa')
plt.xlabel('Index')
plt.ylabel('Retorno Real Percentual')
plt.axhline(0, color='gray', linestyle='--')  # Linha horizontal em y=0
plt.grid()
plt.legend(['Retorno Real EYAC2', 'Retorno Real Ibovespa'])
plt.show()
