# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df1=pd.read_csv('../../camada_ouro/Join_dataframes_new_end.csv')

display(df1)
# Out:
#             Date             Datetime  Close_Real_EYAC2  Volume_EYAC2  \
# 0     2010-01-04  2010-01-04 16:56:00         37.937621   13303743.87
# 1     2010-01-05  2010-01-05 16:56:00         37.774220   21396519.48
# 2     2010-01-06  2010-01-06 16:56:00         38.805357   18720547.15
# 3     2010-01-07  2010-01-07 16:56:00         36.425929   10964646.19
# 4     2010-01-08  2010-01-08 16:56:00         35.037787   14624078.31
# ...          ...                  ...               ...           ...
# 3626  2024-12-20  2024-12-20 16:56:00         38.845595   59277431.74
# 3627  2024-12-23  2024-12-23 16:56:00         39.320157   43785532.81
# 3628  2024-12-26  2024-12-26 16:56:00         37.867609   22920777.53
# 3629  2024-12-27  2024-12-27 16:56:00         36.066818   24167282.36
# 3630  2024-12-30  2024-12-30 16:56:00         36.614223   22355586.67
#
#       Close_Dolar_EYAC2  Price_Dolar_Petro  Volume_Petro Change%_Petro  \
# ...

# %%
df1.describe()
# Out:
#        Close_Real_EYAC2  Volume_EYAC2  Close_Dolar_EYAC2  Price_Dolar_Petro  \
# count       3631.000000  3.631000e+03        3631.000000        3631.000000
# mean          22.663786  5.021059e+07           7.321450          71.585841
# std            8.357270  3.241166e+07           3.894951          20.982274
# min            2.741681  3.249219e+05           0.702617          17.600000
# 25%           16.502374  2.769504e+07           4.785132          53.140000
# 50%           22.549266  4.339195e+07           6.378014          72.260000
# 75%           28.353435  6.419743e+07           8.387037          88.745000
# max           44.940410  4.902302e+08          23.302318         119.780000
#
#        Volume_Petro  Indíce_Ibovespa  Change%_Ibovespa
# count   3631.000000      3631.000000       3630.000000
# mean     276.436717     81473.978158          0.421374
# std      166.013704     27527.860810          8.947391
# min        1.000000     37497.470000        -46.815962
# ...

# %% [markdown]
# O menor valor da ação custa 0,70 dólares, enquanto o maior valor custa 23,30 dólares. Já o barril do petróleo custou no máximo 119,78 dólares e seu mínimo foi de 17,60 dólares

# %%
df1['Date']= pd.to_datetime(df1['Date'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3631 entries, 0 to 3630
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               3631 non-null   datetime64[ns]
#  1   Datetime           3631 non-null   object
#  2   Close_Real_EYAC2   3631 non-null   float64
#  3   Volume_EYAC2       3631 non-null   float64
#  4   Close_Dolar_EYAC2  3631 non-null   float64
#  5   Price_Dolar_Petro  3631 non-null   float64
#  6   Volume_Petro       3631 non-null   float64
#  7   Change%_Petro      3631 non-null   object
#  8   Indíce_Ibovespa    3631 non-null   float64
#  9   Change%_Ibovespa   3630 non-null   float64
#  10  Value_IPCA         3631 non-null   object
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 312.2+ KB

# %%
sns.lineplot(data= df1, x='Date', y= 'Close_Real_EYAC2',palette="tab10", linewidth=1)
# Out:
# C:\Users\YQ693MD\AppData\Local\Temp\ipykernel_12524\2775904524.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data= df1, x='Date', y= 'Close_Real_EYAC2',palette="tab10", linewidth=1)
# <Axes: xlabel='Date', ylabel='Close_Real_EYAC2'>

# %%
sns.lineplot(data= df1, x='Date', y= 'Close_Dolar_EYAC2',palette="tab10", linewidth=2.5)
# Out:
# C:\Users\YQ693MD\AppData\Local\Temp\ipykernel_12524\3298598089.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data= df1, x='Date', y= 'Close_Dolar_EYAC2',palette="tab10", linewidth=2.5)
# <Axes: xlabel='Date', ylabel='Close_Dolar_EYAC2'>

# %% [markdown]
# O dólar foi ficando mais caro com o passar do tempo e após 2016 ele sofreu ums estabilidade.
#  A ação estava valendo mais entre 2010 e 2014, e apartir de 2015 ele começa a descer e estabilizar.

# %%
sns.lineplot(data= df1, x='Date', y= 'Price_Dolar_Petro',palette="tab10", linewidth=2.5)
# Out:
# C:\Users\YQ693MD\AppData\Local\Temp\ipykernel_12524\4116670030.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data= df1, x='Date', y= 'Price_Dolar_Petro',palette="tab10", linewidth=2.5)
# <Axes: xlabel='Date', ylabel='Price_Dolar_Petro'>

# %% [markdown]
# Percebesse que após a pandemia o preço do barril do petróleo foi aumentando

# %%
sns.lineplot(data= df1, x='Date', y= 'Indíce_Ibovespa',palette="tab10", linewidth=2.5)
# Out:
# C:\Users\YQ693MD\AppData\Local\Temp\ipykernel_12524\2300083723.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data= df1, x='Date', y= 'Indíce_Ibovespa',palette="tab10", linewidth=2.5)
# <Axes: xlabel='Date', ylabel='Indíce_Ibovespa'>

# %% [markdown]
# Apartir de 2016

# %%
# Supondo que df1 seja o seu DataFrame original
# Transforme o DataFrame usando melt, excluindo o índice Ibovespa
df_melted = df1.melt(id_vars=['Date'], value_vars=['Price_Dolar_Petro', 'Close_Dolar_EYAC2'], 
                     var_name='Variable', value_name='Value')

# Crie os subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Primeiro gráfico: Price_Dolar_Petro
sns.lineplot(data=df_melted[df_melted['Variable'] == 'Price_Dolar_Petro'], 
             x='Date', y='Value', ax=axes[0], palette="tab10", linewidth=1)
axes[0].set_title('Price Dolar Petro')

# Segundo gráfico: Close_Dolar_EYAC2
sns.lineplot(data=df_melted[df_melted['Variable'] == 'Close_Dolar_EYAC2'], 
             x='Date', y='Value', ax=axes[1], palette="tab10", linewidth=1)
axes[1].set_title('Close Dolar EYAC2')

# Ajuste o layout
plt.tight_layout()

# Exibir os gráficos
plt.show()
# Out:
# C:\Users\YQ693MD\AppData\Local\Temp\ipykernel_12524\2580018539.py:10: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df_melted[df_melted['Variable'] == 'Price_Dolar_Petro'],
# C:\Users\YQ693MD\AppData\Local\Temp\ipykernel_12524\2580018539.py:15: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df_melted[df_melted['Variable'] == 'Close_Dolar_EYAC2'],

# %% [markdown]
# A partir

# %%
# Exemplo com variável numérica
sns.histplot(df1['Close_Dolar_EYAC2'], stat='percent', bins=10)
plt.title('Distribuição percentual da variável')
plt.show()

# %%
# Exemplo com variável numérica
sns.histplot(df1['Price_Dolar_Petro'], stat='percent', bins=10)
plt.title('Distribuição percentual da variável')
plt.show()

# %% [markdown]
# O preço do barril do petróleo é mais volátil que o preço das ações

# %%
sns.histplot(df1['Close_Dolar_EYAC2'])
# Out:
# <Axes: xlabel='Close_Dolar_EYAC2', ylabel='Count'>

# %%
sns.histplot(df1['Price_Dolar_Petro'])
# Out:
# <Axes: xlabel='Price_Dolar_Petro', ylabel='Count'>

# %% [markdown]
# O valor do petróleo tem uam maior variabilidade do que o preçõ da ação

# %%
sns.histplot(df1['Indíce_Ibovespa'])
# Out:
# <Axes: xlabel='Indíce_Ibovespa', ylabel='Count'>

# %% [markdown]
# 1. Influência Direta: Ações Ligadas ao Setor de Petróleo
# • O Ibovespa é composto por várias empresas, e Petrobras (PETR3, PETR4) tem um peso enorme no índice.
# • Como a Petrobras é uma petroleira, o preço do barril de petróleo influencia diretamente seu lucro.
# • Alta no petróleo → tende a aumentar lucro da Petrobras → ações sobem → Ibovespa sobe.
# • Queda no petróleo → pode reduzir lucro → ações caem → impacto negativo no Ibovespa.
# ⸻
# 2. Relação com o Câmbio
# • O petróleo é cotado em dólar, e o Brasil é um exportador de petróleo.
# • Quando o petróleo sobe, pode haver:
# • Entrada de dólares no Brasil (via exportações)
# • Valorização do real (ou menor pressão de desvalorização)
# • Isso pode impactar positivamente o Ibovespa, especialmente empresas que se beneficiam de dólar mais baixo (como varejo e consumo interno).
# ⸻
# 3. Impacto na Inflação e Juros
# • O petróleo afeta o custo dos combustíveis (gasolina, diesel), que influenciam o IPCA (inflação).
# • Alta no petróleo → aumento da inflação → pode levar o Banco Central a subir juros → impacto negativo no Ibovespa.
# • Então, o petróleo também afeta o ciclo de política monetária indiretamente.
# ⸻
# 4. Relação Global e Sentimento de Mercado
# • Alta no petróleo pode sinalizar crescimento global (mais demanda por energia) → otimismo → bolsas sobem.
# • Mas se a alta for por choques de oferta (ex: guerra, crise na OPEP), pode gerar temor de inflação global → bolsas caem.

# %%
sns.boxplot(df1['Close_Dolar_EYAC2'])
# Out:
# <Axes: ylabel='Close_Dolar_EYAC2'>

# %% [markdown]
# O preço da ação apresenta outliers

# %%
sns.boxplot(df1['Close_Real_EYAC2'])
# Out:
# <Axes: ylabel='Close_Real_EYAC2'>

# %%
sns.boxplot(df1['Price_Dolar_Petro'])
# Out:
# <Axes: ylabel='Price_Dolar_Petro'>

# %%
sns.boxplot(df1['Indíce_Ibovespa'])
# Out:
# <Axes: ylabel='Indíce_Ibovespa'>

# %%
# Exemplo: criando uma coluna de retorno percentual
df1['retorno_diario'] = df1['Close_Dolar_EYAC2'].pct_change() * 100
# Gráfico de linha
plt.figure(figsize=(10, 4))
plt.plot(df1['Date'], df1['retorno_diario'])
plt.title('Variação Percentual Diária')
plt.xlabel('Data')
plt.ylabel('% Retorno')
plt.grid(True)
plt.show()
# Histograma com KDE
sns.histplot(df1['retorno_diario'].dropna(), kde=True, bins=30)
plt.title('Distribuição dos Retornos Diários (%)')
plt.xlabel('% Retorno')
plt.show()

# %%
# Exemplo: criando uma coluna de retorno percentual
df1['retorno_diario'] = df1['Price_Dolar_Petro'].pct_change() * 100
# Gráfico de linha
plt.figure(figsize=(10, 4))
plt.plot(df1['Date'], df1['retorno_diario'])
plt.title('Variação Percentual Diária')
plt.xlabel('Data')
plt.ylabel('% Retorno')
plt.grid(True)
plt.show()
# Histograma com KDE
sns.histplot(df1['retorno_diario'].dropna(), kde=True, bins=30)
plt.title('Distribuição dos Retornos Diários (%)')
plt.xlabel('% Retorno')
plt.show()

# %%
correlacao = df1[[ 'Price_Dolar_Petro', 'Close_Dolar_EYAC2']].corr(method='pearson')
print(correlacao)
# Out:
#                    Price_Dolar_Petro  Close_Dolar_EYAC2
# Price_Dolar_Petro           1.000000           0.583167
# Close_Dolar_EYAC2           0.583167           1.000000

# %%
df1[['Price_Dolar_Petro', 'Close_Dolar_EYAC2', 'Indíce_Ibovespa']].corr(method='pearson')
# Out:
#                    Price_Dolar_Petro  Close_Dolar_EYAC2  Indíce_Ibovespa
# Price_Dolar_Petro           1.000000           0.583167        -0.037478
# Close_Dolar_EYAC2           0.583167           1.000000        -0.152904
# Indíce_Ibovespa            -0.037478          -0.152904         1.000000

# %%
plt.scatter(df1['Price_Dolar_Petro'], df1['Close_Dolar_EYAC2'])

# %% [markdown]
# A correlação do preço do barril do petróleo e ação estão diretamento proporcionais, quando o preço do barril do petróleo aumenta a da ação também irá aumentar

# %%
df1[["Close_Real_EYAC2","Indíce_Ibovespa"]].corr(method="pearson")
# Out:
#                   Close_Real_EYAC2  Indíce_Ibovespa
# Close_Real_EYAC2          1.000000         0.784098
# Indíce_Ibovespa           0.784098         1.000000

# %% [markdown]
# # Análise Mensal

# %%
#Cria uma coluna "ano-mês"
df1['ano_mes'] = df1['Date'].dt.to_period('M')

# %%
df1.head(2)
# Out:
#         Date             Datetime  Close_Real_EYAC2  Volume_EYAC2  \
# 0 2010-01-04  2010-01-04 16:56:00         37.937621   13303743.87
# 1 2010-01-05  2010-01-05 16:56:00         37.774220   21396519.48
#
#    Close_Dolar_EYAC2  Price_Dolar_Petro  Volume_Petro Change%_Petro  \
# 0          22.005581              81.51        263.54         2.71%
# 1          21.927335              81.77        258.89         0.32%
#
#    Indíce_Ibovespa  Change%_Ibovespa Value_IPCA  retorno_diario  ano_mes
# 0         70045.08          0.399893      0.75%             NaN  2010-01
# 1         70239.82         -3.775387      0.75%        0.318979  2010-01

# %%
colunas_media = ['Close_Real_EYAC2','Close_Dolar_EYAC2','Volume_EYAC2','Price_Dolar_Petro','Volume_Petro','Indíce_Ibovespa','ano_mes']

df_mean = df1[colunas_media].groupby('ano_mes').apply(lambda x: x.mean())

# %%
df_mean = df_mean.merge(df1[['ano_mes','Value_IPCA']].drop_duplicates(),right_on='ano_mes', left_on='ano_mes',how='left')

# %%
df_mean['Change%_Petro'] = df_mean['Price_Dolar_Petro'].pct_change() * 100
df_mean['Change%_Ibovespa'] = df_mean['Indíce_Ibovespa'].pct_change() * 100

# %%
df_mean.head(5)
# Out:
#    ano_mes  Close_Real_EYAC2  Close_Dolar_EYAC2  Volume_EYAC2  \
# 0  2010-01         35.757273          20.172135  1.794622e+07
# 1  2010-02         33.380246          18.099907  1.860002e+07
# 2  2010-03         36.287428          20.312532  2.077952e+07
# 3  2010-04         33.515000          19.014154  2.056541e+07
# 4  2010-05         29.082431          16.224602  2.322751e+07
#
#    Price_Dolar_Petro  Volume_Petro  Indíce_Ibovespa Value_IPCA  Change%_Petro  \
# 0          78.577222    283.423889     68532.470000      0.75%            NaN
# 1          76.421667    344.457222     65937.581111      0.78%      -2.743232
# 2          81.271364    283.083636     69030.748636      0.52%       6.345971
# 3          84.579474    338.567368     69630.402105      0.57%       4.070450
# 4          73.482105    398.124737     62344.573158      0.43%     -13.120640
#
#    Change%_Ibovespa
# 0               NaN
# 1         -3.786364
# 2          4.691054
# 3          0.868676
# ...

# %% [markdown]
# ### Correlação de Pearson

# %%
df_mean.loc[:, df_mean.columns.difference(['Value_IPCA', 'ano_mes'])].corr(method='pearson')
# Out:
#                    Change%_Ibovespa  Change%_Petro  Close_Dolar_EYAC2  \
# Change%_Ibovespa           1.000000       0.495677          -0.044681
# Change%_Petro              0.495677       1.000000           0.043029
# Close_Dolar_EYAC2         -0.044681       0.043029           1.000000
# Close_Real_EYAC2           0.058256       0.102576           0.412732
# Indíce_Ibovespa            0.102597       0.102287          -0.172348
# Price_Dolar_Petro         -0.079730       0.091873           0.597062
# Volume_EYAC2              -0.052707      -0.069367          -0.604353
# Volume_Petro               0.017303      -0.009105          -0.134296
#
#                    Close_Real_EYAC2  Indíce_Ibovespa  Price_Dolar_Petro  \
# Change%_Ibovespa           0.058256         0.102597          -0.079730
# Change%_Petro              0.102576         0.102287           0.091873
# Close_Dolar_EYAC2          0.412732        -0.172348           0.597062
# ...

# %%
#Valor da inflação como tipo float
df_mean['Inflac_IPCA'] = df_mean['Value_IPCA'].replace({'%':''},regex=True).astype(float)
df_mean['Inflac_IPCA'] = df_mean['Inflac_IPCA'] / 100

# %%
df_mean['Inflac_IPCA']
# Out:
# 0      0.0075
# 1      0.0078
# 2      0.0052
# 3      0.0057
# 4      0.0043
#         ...
# 175   -0.0002
# 176    0.0044
# 177    0.0056
# 178    0.0039
# 179    0.0052
# Name: Inflac_IPCA, Length: 180, dtype: float64

# %%
df_mean.loc[:, df_mean.columns.difference(['Value_IPCA', 'ano_mes'])].corr(method='pearson')
# Out:
#                    Change%_Ibovespa  Change%_Petro  Close_Dolar_EYAC2  \
# Change%_Ibovespa           1.000000       0.495677          -0.044681
# Change%_Petro              0.495677       1.000000           0.043029
# Close_Dolar_EYAC2         -0.044681       0.043029           1.000000
# Close_Real_EYAC2           0.058256       0.102576           0.412732
# Indíce_Ibovespa            0.102597       0.102287          -0.172348
# Inflac_IPCA               -0.102602       0.174608          -0.046303
# Price_Dolar_Petro         -0.079730       0.091873           0.597062
# Volume_EYAC2              -0.052707      -0.069367          -0.604353
# Volume_Petro               0.017303      -0.009105          -0.134296
#
#                    Close_Real_EYAC2  Indíce_Ibovespa  Inflac_IPCA  \
# Change%_Ibovespa           0.058256         0.102597    -0.102602
# Change%_Petro              0.102576         0.102287     0.174608
# Close_Dolar_EYAC2          0.412732        -0.172348    -0.046303
# ...

# %%
# Converter as datas para datetime
df_ibovespa['data'] = pd.to_datetime(df_ibovespa['data'])
# Criar uma coluna "ano-mês"
df_ibovespa['ano_mes'] = df_ibovespa['data'].dt.to_period('M')
# Calcular o retorno mensal do Ibovespa (último valor do mês / primeiro valor do mês - 1)
def retorno_mensal(grupo):
   return (grupo.iloc[-1] / grupo.iloc[0]) - 1
# Agrupar os dados do Ibovespa por mês e calcular o retorno
df_ibovespa_mensal = df_ibovespa.groupby('ano_mes').agg({'fechamento_ibovespa': retorno_mensal})
# Resetando o índice para facilitar a manipulação
df_ibovespa_mensal = df_ibovespa_mensal.reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\YQ693MD\OneDrive - EY\Documents\Oil-Stock\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 2
# ...

# %% [markdown]
# ##### Valor da ação em Real

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(df_mean['Close_Real_EYAC2'], ax=axes[0])
axes[0].set_title('Histograma')
sns.boxplot(df_mean['Close_Real_EYAC2'], ax=axes[1])
axes[1].set_title('Boxplot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Valor da ação em Dólar

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(df_mean['Close_Dolar_EYAC2'], ax=axes[0])
axes[0].set_title('Histograma')
sns.boxplot(df_mean['Close_Dolar_EYAC2'], ax=axes[1])
axes[1].set_title('Boxplot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Valor do barril do petróleo

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(df_mean['Price_Dolar_Petro'], ax=axes[0])
axes[0].set_title('Histograma')
sns.boxplot(df_mean['Price_Dolar_Petro'], ax=axes[1])
axes[1].set_title('Boxplot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Linha do Tempo: Ação em dólar X Barril do Petróleo

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.lineplot(df_mean['Close_Dolar_EYAC2'], ax=axes[0])
axes[0].set_title('Ação em Dólar')
sns.lineplot(df_mean['Price_Dolar_Petro'], ax=axes[1])
axes[1].set_title('Barril de Petróleo')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Correlações

# %% [markdown]
# ##### Ibovespa X Ação em Real

# %%
plt.scatter(df_mean['Indíce_Ibovespa'],df_mean['Close_Real_EYAC2'])

# %% [markdown]
# ##### Barril do Petróleo X Ação em Dólar

# %%
plt.scatter(df_mean['Price_Dolar_Petro'],df_mean['Close_Dolar_EYAC2'])

# %% [markdown]
# ##### Barril do Petróleo X Ação em Real

# %%
plt.scatter(df_mean['Price_Dolar_Petro'],df_mean['Close_Real_EYAC2'])

# %%
df_ibovespa

# %%
# Converter as datas para datetime
df_ibovespa['data'] = pd.to_datetime(df_ibovespa['data'])
# Criar uma coluna "ano-mês"
df_ibovespa['ano_mes'] = df_ibovespa['data'].dt.to_period('M')
# Calcular o retorno mensal do Ibovespa (último valor do mês / primeiro valor do mês - 1)
def retorno_mensal(grupo):
   return (grupo.iloc[-1] / grupo.iloc[0]) - 1
# Agrupar os dados do Ibovespa por mês e calcular o retorno
df_ibovespa_mensal = df_ibovespa.groupby('ano_mes').agg({'fechamento_ibovespa': retorno_mensal})
# Resetando o índice para facilitar a manipulação
df_ibovespa_mensal = df_ibovespa_mensal.reset_index()

# %%
# Agrupar por mês e calcular retorno mensal (último / primeiro - 1)
def retorno_mensal(grupo):
   return (grupo.iloc[-1] / grupo.iloc[0]) - 1
df_mensal = df1.groupby('ano_mes').agg({
   'Price_Dolar_Petro': retorno_mensal,
   'Close_Dolar_EYAC2': retorno_mensal,
   'Indíce_Ibovespa': retorno_mensal
})
# Suponha que você já tenha o IPCA mensal em um DataFrame separado:
df_ipca['ano_mes'] = pd.to_datetime(df_ipca['Date']).dt.to_period('M')
df_ipca_mensal = df_ipca.groupby('ano_mes').agg({'ipca': 'first'})  # ou média
# Juntar os dados
df_final = df_mensal.join(df_ipca_mensal, how='inner')
# Resetar o índice para facilitar a plotagem
df_final = df_final.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 10
#       4 df_mensal = df1.groupby('ano_mes').agg({
#       5    'Price_Dolar_Petro': retorno_mensal,
#       6    'Close_Dolar_EYAC2': retorno_mensal,
#       7    'Indíce_Ibovespa': retorno_mensal
#       8 })
#       9 # Suponha que você já tenha o IPCA mensal em um DataFrame separado:
# ---> 10 df_ipca['ano_mes'] = pd.to_datetime(df_ipca['Date']).dt.to_period('M')
#      11 df_ipca_mensal = df_ipca.groupby('ano_mes').agg({'ipca': 'first'})  # ou média
#      12 # Juntar os dados
#
# NameError: name 'df_ipca' is not defined
