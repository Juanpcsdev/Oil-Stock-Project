# %% [markdown]
# Importação das bibliotecas

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# Leitura do CSV e exibição de dataframe

# %%
df1=pd.read_csv('../../camada_ouro/Join_dataframes_new_end.csv')

display(df1)
# Out:
#            Date  Close_Real_EYAC2  Volume_EYAC2  Close_Dolar_EYAC2  \
# 0    2010-01-29         33.935703   16106857.97          18.284323
# 1    2010-02-26         31.895180   17804380.32          17.368318
# 2    2010-03-31         37.114391   16551869.40          20.546054
# 3    2010-04-30         30.474053   15688008.79          17.322677
# 4    2010-05-28         29.272740   20301487.26          15.804308
# ..          ...               ...           ...                ...
# 175  2024-08-30         36.640116   84437156.59           7.343150
# 176  2024-09-30         36.946330   21146409.59           7.156535
# 177  2024-10-31         34.453725   25596765.78           6.663648
# 178  2024-11-29         38.699903   44011586.42           7.111861
# 179  2024-12-30         36.614223   22355586.67           6.605965
#
#      Price_Dolar_Petro  Volume_Petro  Índice_Ibovespa Year-Month Value_IPCA  \
# 0                72.89        335.27         65401.77     2010-1      0.75%
# ...

# %% [markdown]
# Análise estatística descritiva

# %%
df1.describe()
# Out:
#        Close_Real_EYAC2  Volume_EYAC2  Close_Dolar_EYAC2  Price_Dolar_Petro  \
# count        180.000000  1.800000e+02         180.000000         180.000000
# mean          22.435717  5.266135e+07           7.337062          71.923333
# std            8.092600  3.615007e+07           3.901453          20.989286
# min            5.748161  7.378838e+05           1.481599          21.850000
# 25%           16.328346  2.834781e+07           4.759432          53.927500
# 50%           22.202437  4.168082e+07           6.324505          72.830000
# 75%           27.324615  6.781918e+07           8.421046          89.232500
# max           41.926207  2.624092e+08          20.546054         113.930000
#
#        Volume_Petro  Índice_Ibovespa  Inflac_IPCA  IPCA_Acumulado
# count    180.000000       180.000000   180.000000      180.000000
# mean     237.283028     80947.331000     0.477167        5.867498
# std      148.291101     27321.643369     0.359810        2.325793
# ...

# %% [markdown]
# O menor valor da ação custa 0,70 dólares, enquanto o maior valor custa 23,30 dólares. Já o barril do petróleo custou no máximo 119,78 dólares e seu mínimo foi de 17,60 dólares

# %% [markdown]
# Conversão de coluna para Tipo de Data e Hora

# %%
df1['Date']= pd.to_datetime(df1['Date'])

# %% [markdown]
# Exibição de Informações do DataFrame

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               180 non-null    datetime64[ns]
#  1   Close_Real_EYAC2   180 non-null    float64
#  2   Volume_EYAC2       180 non-null    float64
#  3   Close_Dolar_EYAC2  180 non-null    float64
#  4   Price_Dolar_Petro  180 non-null    float64
#  5   Volume_Petro       180 non-null    float64
#  6   Índice_Ibovespa    180 non-null    float64
#  7   Year-Month         180 non-null    object
#  8   Value_IPCA         180 non-null    object
#  9   Inflac_IPCA        180 non-null    float64
#  10  IPCA_Acumulado     180 non-null    float64
# dtypes: datetime64[ns](1), float64(8), object(2)
# memory usage: 15.6+ KB

# %% [markdown]
# # Análise Mensal

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(data= df1, x='Date', y= 'Close_Real_EYAC2', color='#41afda', label='Real') #Real
sns.lineplot(data= df1, x='Date', y= 'Close_Dolar_EYAC2',color='#2c39a8', label='Dólar') #Dolar
plt.fill_between(df1['Date'], df1['Close_Real_EYAC2'], color='#41afda', alpha=1) #Real
plt.fill_between(df1['Date'], df1['Close_Dolar_EYAC2'], color='#2c39a8', alpha=1) #Dolar
plt.title('Variação mensal entre a Ação em Real e Dólar')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.legend()
plt.show()

# %% [markdown]
# Fig1.: De 2010 a 2014, o Dólar teve uma leve alta, enquanto o Real se manteve mais estável. Entre 2015 e 2016, o Dólar disparou devido a fatores políticos, como o impeachment, resultando na desvalorização do Real. De 2017 a 2019, o Dólar se estabilizou, mas o Real continuou a oscilar. Em 2020, a pandemia causou uma forte alta no Dólar e uma desvalorização do Real. Após 2020, o Dólar permaneceu alto, com o Real apresentando variações mais acentuadas. Em resumo, o gráfico reflete a desvalorização do Real frente ao Dólar, com picos relacionados a eventos políticos e a crise da pandemia.

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(data= df1, x='Date', y= 'Price_Dolar_Petro', color='#41afda')
plt.fill_between(df1['Date'], df1['Price_Dolar_Petro'], color='#41afda', alpha=0.5)
plt.title('Variação mensal do preço do barril de petróleo')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.show()

# %% [markdown]
# Fig2:. Entre 2010 e 2014, houve altos e baixos, com picos significativos até 2011 e uma queda até 2014. Entre 2015 e 2016, o preço caiu drasticamente devido a uma sobreoferta e desaceleração econômica. De 2017 a 2019, o preço se recuperou gradualmente, com flutuações moderadas. Em 2020, a pandemia provocou uma queda abrupta nos preços devido à redução da demanda global. Após 2020, os preços começaram a se recuperar, com uma alta acentuada a partir de 2022, estabilizando-se em 2023. O gráfico reflete a volatilidade do mercado de petróleo, influenciado por fatores econômicos, políticos e a pandemia.

# %%
df1.head()
# Out:
#         Date  Close_Real_EYAC2  Volume_EYAC2  Close_Dolar_EYAC2  \
# 0 2010-01-29         33.935703   16106857.97          18.284323
# 1 2010-02-26         31.895180   17804380.32          17.368318
# 2 2010-03-31         37.114391   16551869.40          20.546054
# 3 2010-04-30         30.474053   15688008.79          17.322677
# 4 2010-05-28         29.272740   20301487.26          15.804308
#
#    Price_Dolar_Petro  Volume_Petro  Índice_Ibovespa Year-Month Value_IPCA  \
# 0              72.89        335.27         65401.77     2010-1      0.75%
# 1              79.66        319.04         66503.27     2010-2      0.78%
# 2              83.76        371.96         70371.54     2010-3      0.52%
# 3              86.15        392.14         67529.73     2010-4      0.57%
# 4              73.97        420.67         61946.99     2010-5      0.43%
#
#    Inflac_IPCA  IPCA_Acumulado
# 0         0.75        4.312028
# 1         0.78        4.592325
# 2         0.52        4.831572
# ...

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(data= df1, x='Date', y= 'Índice_Ibovespa',palette="tab10", linewidth=2.5)
plt.fill_between(df1['Date'], df1['Índice_Ibovespa'], color='#41afda', alpha=0.5)
plt.title('Variação mensal do Índice do Ibovespa')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.show()
# Out:
# C:\Users\YQ693MD\AppData\Local\Temp\ipykernel_10152\2864958929.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data= df1, x='Date', y= 'Índice_Ibovespa',palette="tab10", linewidth=2.5)

# %% [markdown]
# Fig3:. Entre 2010 e 2014, o índice teve um crescimento moderado, mas começou a cair em 2014 devido à desaceleração econômica e instabilidade política. De 2015 a 2016, o índice sofreu uma queda acentuada devido à crise econômica e política no Brasil. Entre 2017 e 2019, houve uma recuperação gradual, impulsionada pela estabilização política e recuperação econômica. Em 2020, o índice despencou devido à pandemia, mas se recuperou rapidamente. A partir de 2021, o Índice Bovespa mostra um crescimento contínuo, alcançando altos níveis em 2023 e 2024, refletindo uma forte recuperação pós-pandemia.

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(data= df1, x='Date', y= 'Price_Dolar_Petro', color='#B15E85',linewidth=1.5, label='Barril de Petróleo')
sns.lineplot(data= df1, x='Date', y= 'Close_Dolar_EYAC2',color='#212ea2', linewidth=1.5, label='Ação em Dólar') 
plt.fill_between(df1['Date'], df1['Price_Dolar_Petro'], color='#B15E85', alpha=0.7) 
plt.fill_between(df1['Date'], df1['Close_Dolar_EYAC2'], color='#212ea2', alpha=0.6) 
plt.title('Variação mensal entre a ação dólar e o barril de petróleo')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.legend()
plt.show()

# %% [markdown]
# Fig4:. Entre 2010 e 2014, o preço do petróleo apresentou flutuações, enquanto o Dólar se manteve estável até 2014, quando começou a subir. Entre 2015 e 2016, o petróleo caiu acentuadamente, e o Dólar subiu, refletindo a crise econômica e política no Brasil. De 2017 a 2019, o petróleo se recuperou parcialmente, enquanto o Dólar se estabilizou. Em 2020, ambos os indicadores sofreram grandes flutuações devido à pandemia, com o petróleo caindo e o Dólar se valorizando. A partir de 2021, o preço do petróleo se recupera e atinge picos em 2022-2024, enquanto o Dólar se estabiliza após os picos de 2020. O gráfico mostra a relação entre os dois indicadores, com altos e baixos refletindo eventos econômicos e a recuperação pós-pandemia.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['Close_Dolar_EYAC2'], stat='percent', bins=10)
plt.title('Distribuição percentual da ação em Dólar')
plt.xlabel('Valor')
plt.ylabel('Porcentagem')
plt.show()

# %% [markdown]
# Fig5:. O gráfico revela que a ação do Dólar tem uma distribuição concentrada em valores mais baixos, especialmente entre 2.5 e 7.5, com um pico maior em torno de 5.0. À medida que o valor do Dólar aumenta, a frequência das observações diminui. Isso indica que, durante o período analisado, o valor do Dólar passou a maior parte do tempo em níveis mais baixos, com uma menor ocorrência de valores mais altos.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['Price_Dolar_Petro'], stat='percent', bins=10)
plt.title('Distribuição percentual do barril de petróleo')
plt.xlabel('Valor')
plt.ylabel('Porcentagem')
plt.show()

# %% [markdown]
# Fig6:. O gráfico mostra uma distribuição percentual do preço do barril de petróleo, com maior concentração de ocorrências entre os valores de 40 e 60. A distribuição é mais equilibrada entre os intervalos de 20 a 80, enquanto preços muito baixos ou muito altos são menos frequentes, com uma concentração menor em extremos de preço.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['Close_Dolar_EYAC2'])
plt.title('Distribuição da ação em Dólar')
plt.xlabel('Valor')
plt.ylabel('Contagem')
plt.show()

# %% [markdown]
# Fig7:. O gráfico mostra que o Dólar teve maior concentração de ocorrências em valores baixos, especialmente entre 2,5 e 5, com uma queda significativa na frequência à medida que o valor do Dólar aumentava. As ocorrências em intervalos mais altos (acima de 10) foram raras, sugerindo que o Dólar passou a maior parte do tempo em valores mais baixos ao longo do período analisado.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['Price_Dolar_Petro'])
plt.title('Distribuição do barril de petróleo')
plt.xlabel('Valor')
plt.ylabel('Contagem')
plt.show()

# %% [markdown]
# Fig8:. O gráfico mostra uma distribuição mais frequente dos preços do barril de petróleo entre 40 e 80, com uma tendência equilibrada entre os intervalos. A maior parte das observações ocorre nesses valores médios, enquanto preços muito baixos (abaixo de 20) ou muito altos (acima de 80) ocorreram com menos frequência.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['Índice_Ibovespa'])
plt.title('Distribuição do Índice do Ibovespa')
plt.xlabel('Valor')
plt.ylabel('Contagem')
plt.show()

# %% [markdown]
# Fig9:. O gráfico mostra que o Índice Bovespa teve maior concentração de ocorrências entre 60.000 e 80.000, com uma diminuição progressiva à medida que o valor do índice aumentava. Valores acima de 100.000 e abaixo de 40.000 foram raros, com o gráfico destacando uma distribuição mais concentrada em valores intermediários.

# %% [markdown]
# # Outliers

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(df1['Close_Dolar_EYAC2'])
plt.title('Boxplot da ação em Dólar')
plt.ylabel('Distribuição')
plt.show()

# %% [markdown]
# Fig10:. Este boxplot revela que a maior parte dos valores da ação do Dólar estão concentrados entre 5.0 e 9.0, com a mediana perto de 7.0. Os valores da ação do Dólar mostram uma distribuição relativamente centralizada, com alguns valores atípicos (outliers) que estão acima de 9.0, indicando possíveis variações incomuns ou eventos que causaram picos nos preços.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(df1['Close_Real_EYAC2'])
plt.title('Boxplot da ação em Real')
plt.ylabel('Distribuição')
plt.show()

# %% [markdown]
# Fig11:. Este boxplot revela que a maior parte dos valores da ação do Real estão concentrados entre 20.0 e 30.0, com a mediana em torno de 25.0. A distribuição parece ser relativamente simétrica, sem valores extremos ou outliers. A variação da ação do Real é moderada, com dados distribuídos de maneira equilibrada dentro da faixa interquartil.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(df1['Price_Dolar_Petro'])
plt.title('Boxplot do barril de petróleo')
plt.ylabel('Distribuição')
plt.show()

# %% [markdown]
# Fig12:. Este boxplot revela que o preço do barril de petróleo se concentra entre 70 e 90, com a mediana em torno de 80. A distribuição dos preços é relativamente estável e simétrica, sem valores extremos ou outliers. A variação do preço do petróleo, ao longo do período analisado, parece ter sido moderada, com a maioria dos preços se mantendo dentro de uma faixa estreita.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(df1['Índice_Ibovespa'])
plt.title('Boxplot do Índice do Ibovespa')
plt.ylabel('Distribuição')
plt.show()

# %% [markdown]
# Fig13:. Este boxplot revela que o Índice Bovespa se concentrou entre 50.000 e 70.000, com a mediana em torno de 60.000. A distribuição dos valores é relativamente compacta, sem grandes variações ou outliers, sugerindo que o índice esteve estável dentro dessa faixa ao longo do período analisado. A variação total dos valores ficou entre 40.000 e 80.000, com uma distribuição simétrica e sem grandes flutuações.

# %%
df_retorno = df1.copy()
df_retorno['retorno_diario'] = df_retorno['Close_Dolar_EYAC2'].pct_change() * 100

#Gráfico de linha
plt.figure(figsize=(10, 4))
plt.plot(df_retorno['Date'], df_retorno['retorno_diario'])
plt.title('Variação Percentual Mensal da ação em dólar')
plt.xlabel('Data')
plt.ylabel('% Retorno')
plt.grid(True)
plt.show()

#Histograma com KDE
sns.histplot(df_retorno['retorno_diario'].dropna(), kde=True, bins=30)
plt.title('Distribuição dos Retornos Mensal (%)')
plt.xlabel('% Retorno')
plt.show()

# %% [markdown]
# Fig14:. O gráfico de linha mostra uma alta volatilidade mensal na variação percentual do Dólar, com grandes picos e quedas, especialmente em momentos de instabilidade econômica e política como 2015-2016 e 2020. Não há uma tendência clara, mas sim flutuações constantes no valor do Dólar. O histograma revela que a maior parte dos retornos mensais do Dólar está concentrada entre -20% e 20%, com mais ocorrências negativas, especialmente entre -20% e -10%, sugerindo períodos de desvalorização do Dólar. Embora haja picos de valorização extrema, esses são raros. A distribuição é assimétrica, com mais frequências de retornos negativos do que positivos.

# %%
df_retorno2 = df1.copy()

df_retorno2['retorno_diario'] = df_retorno2['Price_Dolar_Petro'].pct_change() * 100

#Gráfico de linha
plt.figure(figsize=(10, 4))
plt.plot(df_retorno2['Date'], df_retorno2['retorno_diario'])
plt.title('Variação Percentual Mensal do barril de petróleo')
plt.xlabel('Data')
plt.ylabel('% Retorno')
plt.grid(True)
plt.show()

#Histograma com KDE
sns.histplot(df_retorno2['retorno_diario'].dropna(), kde=True, bins=30)
plt.title('Distribuição dos Retornos Mensal (%)')
plt.xlabel('% Retorno')
plt.show()

# %% [markdown]
# Fig15:. Os gráficos mostram a variação percentual mensal da ação do barril de petróleo e a distribuição dos retornos mensais dessa ação. O gráfico de linha revela uma volatilidade alta, com grandes picos e quedas, especialmente em 2014-2016 e 2020, indicando grandes flutuações no valor do petróleo, influenciadas por crises globais. O histograma mostra uma distribuição assimétrica, com maior concentração de retornos negativos entre -20% e 0%, sugerindo que o petróleo teve mais meses de queda do que de alta. Embora haja picos de grandes ganhos (acima de 20%), esses são raros. A distribuição tem uma cauda longa à direita, refletindo que grandes aumentos no preço do barril são eventos mais excepcionais.

# %% [markdown]
# # Correlações

# %% [markdown]
# ##### Correlação Barril de Petróleo e Ação em Dólar

# %%
df1[['Price_Dolar_Petro', 'Close_Dolar_EYAC2']].corr(method='pearson')
# Out:
#                    Price_Dolar_Petro  Close_Dolar_EYAC2
# Price_Dolar_Petro           1.000000           0.590178
# Close_Dolar_EYAC2           0.590178           1.000000

# %%
plt.figure(figsize=(10, 6))
x = df1['Price_Dolar_Petro']
y = df1['Close_Dolar_EYAC2']
plt.scatter(x, y)
plt.title('Correlação entre os preços do barril de petróleo e a ação em Dólar')
plt.xlabel('Preço Barril')
plt.ylabel('Preço Ação')

#Linha de tendência
z = np.polyfit(x,y,1)
p = np.polyval(z, x)
plt.plot(x, p, color='red')

plt.show()

# %% [markdown]
# Fig16:. O gráfico mostra uma correlação positiva entre o preço do barril de petróleo e a ação do Dólar, indicando que esses dois fatores tendem a subir ou descer juntos. Embora a correlação seja visível, os dados não são perfeitamente lineares, sugerindo que outros fatores além do preço do petróleo também influenciam o valor da ação do Dólar.

# %%
df1[["Close_Real_EYAC2","Índice_Ibovespa"]].corr(method="pearson")
# Out:
#                   Close_Real_EYAC2  Índice_Ibovespa
# Close_Real_EYAC2          1.000000         0.784836
# Índice_Ibovespa           0.784836         1.000000

# %%
plt.figure(figsize=(10, 6))
x = df1['Índice_Ibovespa']
y = df1['Close_Real_EYAC2']
plt.scatter(x, y)
plt.title('Correlação entre o índice do Ibovespa e Ação em Real')
plt.xlabel('Ibovespa')
plt.ylabel('Ação')

#Linha de tendência
z = np.polyfit(x,y,1)
p = np.polyval(z, x)
plt.plot(x, p, color='red')

plt.show()

# %% [markdown]
# Fig17:. O gráfico mostra uma correlação positiva moderada a forte entre o Índice Bovespa e a ação em Real, indicando que, geralmente, quando o índice da bolsa de valores brasileira aumenta, a ação em Real também tende a subir. No entanto, há uma certa dispersão nos dados, sugerindo que fatores além do Índice Bovespa influenciam a ação em Real.

# %% [markdown]
# # Análise Mensal

# %%
#Criação de uma coluna ano/mes
df1['ano_mes'] = df1['Date'].dt.to_period('M')

# %%
df1.head(2)
# Out:
#         Date  Close_Real_EYAC2  Volume_EYAC2  Close_Dolar_EYAC2  \
# 0 2010-01-29         33.935703   16106857.97          18.284323
# 1 2010-02-26         31.895180   17804380.32          17.368318
#
#    Price_Dolar_Petro  Volume_Petro  Índice_Ibovespa Year-Month Value_IPCA  \
# 0              72.89        335.27         65401.77     2010-1      0.75%
# 1              79.66        319.04         66503.27     2010-2      0.78%
#
#    Inflac_IPCA  IPCA_Acumulado  ano_mes
# 0         0.75        4.312028  2010-01
# 1         0.78        4.592325  2010-02

# %%
#Selecionando apenas os valores de fechamentos mensais

colunas_media = ['Close_Real_EYAC2','Close_Dolar_EYAC2','Volume_EYAC2','Price_Dolar_Petro','Volume_Petro','Índice_Ibovespa','ano_mes']

list_dates = []

#Adicionando valores do fechamento (último dia) de cada mês
for x in range (2010,2025):
    for y in range (1,13):
        list_dates.append(list(df1[(df1['Date'].dt.year==x) & (df1['Date'].dt.month == y)].iloc[-1]))

#Transformando em dataframe com colunas selecionadas
df_mean = pd.DataFrame(list_dates, columns=df1.columns)
df_mean = df_mean[colunas_media]

# %%
#União da tabela de fechamento com os valores de Inflação mensais
df_mean = df_mean.merge(df1[['ano_mes','Value_IPCA']].drop_duplicates(),right_on='ano_mes', left_on='ano_mes',how='left')

# %%
df_mean.tail(2)
# Out:
#      Close_Real_EYAC2  Close_Dolar_EYAC2  Volume_EYAC2  Price_Dolar_Petro  \
# 178         38.699903           7.111861   44011586.42              67.72
# 179         36.614223           6.605965   22355586.67              70.53
#
#      Volume_Petro  Índice_Ibovespa  ano_mes Value_IPCA
# 178        106.39        125667.83  2024-11      0.39%
# 179         93.10        120283.40  2024-12      0.52%

# %%
# df_mean['Change%_Petro'] = df_mean['Price_Dolar_Petro'].pct_change() * 100
# df_mean['Change%_Ibovespa'] = df_mean['Índice_Ibovespa'].pct_change() * 100

# %%
#Valor da inflação como tipo float
df_mean['Inflac_IPCA'] = df_mean['Value_IPCA'].replace({'%':''},regex=True).astype(float)

# %%
#Adicionando coluna de inflação acumulada em 12 meses

lista_ipca = []

for i in df_mean.index:
    taxas_inflacao = [x for x in df_mean['Inflac_IPCA'].iloc[max(0, i-12):i] / 100]
    #Calculando a inflação acumulada
    inflacao_acumulada = 1
    for taxa in taxas_inflacao:
        inflacao_acumulada *= (1 + taxa)

    inflacao_acumulada -= 1
    inflacao_acumulada = inflacao_acumulada * 100  #Convertendo para porcentagem
    lista_ipca.append(inflacao_acumulada)

df_mean['IPCA_Acumulado'] = lista_ipca

# %%
#Transformando coluna ano/mes em timestamp
df_mean['Date'] = df_mean['ano_mes'].dt.to_timestamp()

# %% [markdown]
# ### Correlação de Pearson

# %%
df_mean.loc[:, df_mean.columns.difference(['Value_IPCA', 'ano_mes'])].corr(method='pearson')
# Out:
#                    Close_Dolar_EYAC2  Close_Real_EYAC2      Date  \
# Close_Dolar_EYAC2           1.000000          0.416398 -0.599116
# Close_Real_EYAC2            0.416398          1.000000  0.458312
# Date                       -0.599116          0.458312  1.000000
# IPCA_Acumulado             -0.315999         -0.278918  0.021058
# Inflac_IPCA                -0.061582         -0.116968 -0.084649
# Price_Dolar_Petro           0.590178          0.334877 -0.300372
# Volume_EYAC2               -0.408844          0.094457  0.489724
# Volume_Petro                0.077440         -0.467907 -0.493074
# Índice_Ibovespa            -0.169058          0.784836  0.858894
#
#                    IPCA_Acumulado  Inflac_IPCA  Price_Dolar_Petro  \
# Close_Dolar_EYAC2       -0.315999    -0.061582           0.590178
# Close_Real_EYAC2        -0.278918    -0.116968           0.334877
# Date                     0.021058    -0.084649          -0.300372
# ...

# %% [markdown]
# ##### Valor da ação em Real

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(df_mean['Close_Real_EYAC2'], ax=axes[0])
axes[0].set_title('Histograma')
axes[0].set_xlabel('Distribuição da ação')
axes[0].set_ylabel('Contagem')

sns.boxplot(df_mean['Close_Real_EYAC2'], ax=axes[1])
axes[1].set_title('Boxplot')
axes[1].set_ylabel('Distribuição')

plt.tight_layout()
plt.show()

# %% [markdown]
# Fig18:. O histograma e o boxplot mostram que a maior parte dos valores da ação se concentra em torno de 25, com pouca dispersão e sem valores extremos. A distribuição é relativamente simétrica, com uma concentração de dados entre 20 e 30 e uma ausência de outliers. Isso indica que a ação tem um comportamento estável e centralizado, sem grandes variações.

# %% [markdown]
# ##### Valor da ação em Dólar

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(df_mean['Close_Dolar_EYAC2'], ax=axes[0])
axes[0].set_title('Histograma')
axes[0].set_xlabel('Distribuição da ação')
axes[0].set_ylabel('Contagem')

sns.boxplot(df_mean['Close_Dolar_EYAC2'], ax=axes[1])
axes[1].set_title('Boxplot')
axes[1].set_ylabel('Distribuição')

plt.tight_layout()
plt.show()

# %% [markdown]
# Fig19:. O histograma e o boxplot indicam que o valor do Real está concentrado em torno de 5 a 7, com maior frequência de observações dentro dessa faixa. A dispersão é moderada, com alguns valores mais altos (acima de 8) representando outliers. A distribuição é relativamente estável, sem grandes flutuações. A ação do Real tem um comportamento centralizado, com valores menos frequentes mais distantes dessa faixa.

# %% [markdown]
# ##### Valor do barril do petróleo

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(df_mean['Price_Dolar_Petro'], ax=axes[0])
axes[0].set_title('Histograma')
axes[0].set_xlabel('Distribuição do barril de petróleo')
axes[0].set_ylabel('Contagem')

sns.boxplot(df_mean['Price_Dolar_Petro'], ax=axes[1])
axes[1].set_title('Boxplot')
axes[1].set_ylabel('Distribuição')

plt.tight_layout()
plt.show()

# %% [markdown]
# Fig20:. O histograma e o boxplot mostram que o preço do barril de petróleo é mais frequentemente encontrado entre 60 e 80, com uma concentração significativa de dados nessa faixa. A mediana está em torno de 80, e 50% dos valores estão entre 60 e 90. O gráfico mostra uma dispersão moderada, com algumas observações acima de 100 sendo outliers. Em resumo, o preço do barril de petróleo é relativamente estável dentro dessa faixa, mas há variações mais extremas, embora raras.

# %% [markdown]
# ##### Linha do Tempo: Ação em dólar X Barril do Petróleo

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

#Barril de Petróleo
ax1.set_xlabel('Data')
ax1.set_ylabel('Barril de Petróleo', color='black')
ax1.plot(df_mean['Date'], df_mean['Price_Dolar_Petro'], color='black', label='Barril de Petróleo', linewidth=1)
ax1.tick_params(axis='y', labelcolor='black')
plt.legend()

#Ação
ax2 = ax1.twinx()  
ax2.set_ylabel('Ação', color='orange')
ax2.plot(df_mean['Date'], df_mean['Close_Dolar_EYAC2'], color='orange', alpha=1, label='Ação em Dólar')
ax2.tick_params(axis='y', labelcolor='orange')

plt.legend()
plt.title('Comparação entre o barril de petróleo e ação em dólar')
fig.tight_layout()
plt.show()

# %% [markdown]
# Fig21:. O gráfico ilustra uma correlação complexa entre o preço do barril de petróleo e a ação do Dólar. Embora inicialmente apresentem uma relação inversa (2010-2014), a partir de 2015, eles mostram comportamentos mais independentes, com picos de volatilidade relacionados a crises globais e flutuações nos mercados financeiros. O período pós-2020 indica uma recuperação, com o preço do petróleo subindo e a ação do Dólar permanecendo mais estável.

# %%
# fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# sns.lineplot(x=df_mean['Date'],y=df_mean['Close_Dolar_EYAC2'], ax=axes[0])
# axes[0].set_title('Variação mensal da ação em dólar ')
# axes[0].set_xlabel('Ano-mês')
# axes[0].set_ylabel('Valor')


# sns.lineplot(x=df_mean['Date'],y=df_mean['Price_Dolar_Petro'], ax=axes[1], color='purple')
# axes[1].set_title('Variação mensal do barril de petróleo')
# axes[1].set_xlabel('Ano-mês')
# axes[1].set_ylabel('Valor')


# plt.tight_layout()
# plt.show()

# %% [markdown]
# #### Correlações Part.2

# %% [markdown]
# ##### Ibovespa X Ação em Real

# %%
plt.figure(figsize=(10, 6))
x = df_mean['Índice_Ibovespa']
y = df_mean['Close_Real_EYAC2']
plt.scatter(x, y)
plt.title('Correlação entre o índice do Ibovespa e a ação em Real')
plt.xlabel('Ibovespa')
plt.ylabel('Ação em Real')

#Linha de tendência
z = np.polyfit(x,y,1)
p = np.polyval(z, x)
plt.plot(x, p, color='red')

plt.show()

# %% [markdown]
# Fig22:. O gráfico revela uma correlação positiva moderada a forte entre o Índice Bovespa e a ação em Real, indicando que quando o Índice Bovespa aumenta, o valor da ação em Real também tende a aumentar. No entanto, há uma certa dispersão nos dados, sugerindo que a relação entre esses dois indicadores não é completamente linear, e outros fatores podem influenciar o comportamento da ação em Real.

# %% [markdown]
# ##### Barril do Petróleo X Ação em Dólar

# %%
plt.figure(figsize=(10, 6))
x = df_mean['Price_Dolar_Petro']
y = df_mean['Close_Dolar_EYAC2']
plt.scatter(x, y)
plt.title('Correlação entre os preços do barril de petróleo e a ação em Dólar')
plt.xlabel('Barril de Petróleo')
plt.ylabel('Ação em Dólar')

#Linha de tendência
z = np.polyfit(x,y,1)
p = np.polyval(z, x)
plt.plot(x, p, color='red')

plt.show()

# %% [markdown]
# Fig23:. O gráfico revela uma correlação positiva moderada a forte entre o preço do barril de petróleo e a ação em Dólar, indicando que os aumentos no preço do petróleo tendem a ser acompanhados por aumentos na ação do Dólar. No entanto, há uma dispersão nos dados, sugerindo que a relação não é perfeita e que outros fatores também afetam a ação do Dólar.

# %%
df_mean[['IPCA_Acumulado', 'Índice_Ibovespa']].corr(method='pearson')
# Out:
#                  IPCA_Acumulado  Índice_Ibovespa
# IPCA_Acumulado         1.000000        -0.182618
# Índice_Ibovespa       -0.182618         1.000000

# %%
plt.figure(figsize=(10, 6))
x = df_mean['IPCA_Acumulado']
y = df_mean['Índice_Ibovespa']
plt.scatter(x, y)
plt.title('Correlação entre os preços do barril de petróleo e a ação em Dólar')
plt.xlabel('Barril de Petróleo')
plt.ylabel('Ação em Dólar')

#Linha de tendência
z = np.polyfit(x,y,1)
p = np.polyval(z, x)
plt.plot(x, p, color='red')

plt.show()

# %% [markdown]
# Fig24:. O gráfico revela uma correlação fraca entre o Índice Bovespa e o IPCA, com grande dispersão nos dados e sem uma relação linear clara. Isso sugere que o desempenho do Índice Bovespa não é diretamente influenciado pelas variações do IPCA, e outros fatores econômicos podem ser mais relevantes para explicar essas flutuações.

# %% [markdown]
# ##### Variações

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

#Ibovespa
ax1.set_xlabel('Data')
ax1.set_ylabel('Ibovespa', color='blue')
ax1.plot(df_mean['Date'], df_mean['Índice_Ibovespa'], color='blue', label='Ibovespa', linewidth=1)
ax1.tick_params(axis='y', labelcolor='blue')

#IPCA
ax2 = ax1.twinx()  
ax2.set_ylabel('Ação em Real', color='orange')
ax2.plot(df_mean['Date'], df_mean['Close_Real_EYAC2'], color='orange', alpha=1, label='Ação', linewidth=1)
ax2.tick_params(axis='y', labelcolor='orange')


plt.title('Comparação entre Ibovespa e Ação')
fig.tight_layout()
plt.show()

# %% [markdown]
# Fig25:. O gráfico sugere que o Índice Bovespa e a Ação em Real têm uma relação positiva, com ambos os valores crescendo ao longo do tempo, especialmente a partir de 2016. A Ação em Real tem um crescimento mais suave, enquanto o Índice Bovespa apresenta mais volatilidade, especialmente em 2020. A recuperação pós-2020 foi visível para ambos, mas com a Ação em Real respondendo de forma mais estável às flutuações. A diferença de escala entre as duas variáveis é importante, com o Índice Bovespa apresentando valores muito mais altos.

# %%
df_mean[['IPCA_Acumulado','Índice_Ibovespa']].corr(method='pearson')
# Out:
#                  IPCA_Acumulado  Índice_Ibovespa
# IPCA_Acumulado         1.000000        -0.182618
# Índice_Ibovespa       -0.182618         1.000000

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

#Ibovespa
ax1.set_xlabel('Data')
ax1.set_ylabel('Ibovespa', color='blue')
ax1.plot(df_mean['Date'], df_mean['Índice_Ibovespa'], color='blue', label='Ibovespa', linewidth=1)
ax1.tick_params(axis='y', labelcolor='blue')
plt.legend()
#IPCA
ax2 = ax1.twinx()  
ax2.set_ylabel('IPCA', color='red')
ax2.plot(df_mean['Date'], df_mean['IPCA_Acumulado'], color='red', alpha=1, label='IPCA')
ax2.tick_params(axis='y', labelcolor='red')

plt.legend()
plt.title('Comparação entre Ibovespa e IPCA')
fig.tight_layout()
plt.show()

# %% [markdown]
# Fig26:. O gráfico ilustra como o Índice Bovespa e o IPCA evoluíram ao longo do tempo, com o Índice Bovespa mostrando flutuações mais pronunciadas e picos de valorização após 2020, enquanto o IPCA cresce de forma mais estável. A análise sugere que o mercado de ações e a inflação no Brasil não estão fortemente correlacionados, com os primeiros sendo mais afetados por fatores externos e o segundo mais relacionado à política econômica interna.

# %%
df_mean[['IPCA_Acumulado','Close_Real_EYAC2']].corr(method='pearson')
# Out:
#                   IPCA_Acumulado  Close_Real_EYAC2
# IPCA_Acumulado          1.000000         -0.278918
# Close_Real_EYAC2       -0.278918          1.000000

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

#Ibovespa
ax1.set_xlabel('Data')
ax1.set_ylabel('Ação', color='orange')
ax1.plot(df_mean['Date'], df_mean['Close_Real_EYAC2'], color='orange', label='Ação', linewidth=1)
ax1.tick_params(axis='y', labelcolor='orange')
plt.legend()
#IPCA
ax2 = ax1.twinx()  
ax2.set_ylabel('IPCA', color='red')
ax2.plot(df_mean['Date'], df_mean['IPCA_Acumulado'], color='red', alpha=1, label='IPCA')
ax2.tick_params(axis='y', labelcolor='red')

plt.legend()
plt.title('Comparação entre Ação e IPCA')
fig.tight_layout()
plt.show()

# %% [markdown]
# Fig27:. O gráfico mostra uma relação entre a ação em Real e o IPCA, com ambos apresentando crescimento gradual, especialmente após 2016, mas com comportamentos diferentes. O IPCA tem variações mais intensas, com picos de inflação, enquanto a ação em Real tem uma tendência de valorização mais estável, embora também tenha seus próprios picos, especialmente durante a recuperação econômica pós-2020. O gráfico sugere uma interdependência, mas com diferentes respostas às crises econômicas e aos fatores que afetam o mercado.

# %%
#Criando um gráfico para comparação
plt.figure(figsize=(20, 7))
plt.plot(df_mean['Date'], df_mean['Close_Real_EYAC2'].pct_change() * 100, label='Ação EYAC2', color='#90bce6')
plt.plot(df_mean['Date'], df_mean['Índice_Ibovespa'].pct_change() * 100, label='Índice de Fechamento do Ibovespa', color='blue')
plt.plot(df_mean['Date'], df_mean['IPCA_Acumulado'], label='Inflação Acumulada (IPCA)', color='red')

plt.title('Variação mensal entre o Índice do Ibovespa, IPCA e ação de petróleo')
plt.xlabel('Data')
plt.ylabel('Percentual')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Fig28:. O gráfico mostra como a ação, o Índice Bovespa e o IPCA evoluíram ao longo do tempo. A ação apresenta grande volatilidade, com picos acentuados principalmente até 2016, enquanto o IPCA segue uma tendência mais controlada, com crescimento constante após 2020. A correlação entre a ação e a inflação não é perfeita, com a ação sendo mais sensível a eventos externos, enquanto o IPCA mostra um comportamento mais previsível e controlado.

# %%
# Exemplo de valores percentuais anuais
variacao_ibovespa = df_mean['Índice_Ibovespa'].pct_change() # Variação percentual do Ibovespa
inflacao_ipca = df_mean['IPCA_Acumulado']       # Inflação IPCA
variacao_acao = df_mean['Close_Real_EYAC2'].pct_change()      # Variação percentual da sua ação

# Cálculo da taxa de juros real do Ibovespa e da ação
df_mean['taxa_real_ibovespa'] = ((1 + variacao_ibovespa) / (1 + inflacao_ipca / 100) - 1) * 100
df_mean['taxa_real_acao'] = ((1 + variacao_acao) / (1 + inflacao_ipca / 100) - 1) * 100

# %%
#Criando um gráfico para comparação
plt.figure(figsize=(14, 7))
plt.plot(df_mean['Date'], df_mean['taxa_real_acao'], label='Ação em Real', color='yellow')
plt.plot(df_mean['Date'], df_mean['taxa_real_ibovespa'], label='Ibovespa', color='blue')

plt.title('Ganho real entre o Índice do Ibovespa e a ação de petróleo ajustados pela inflação')
plt.xlabel('Data')
plt.ylabel('Percentual')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Fig29:. O gráfico ilustra a volatilidade e os ganhos reais ajustados pela inflação de duas variáveis-chave: o Índice Bovespa e a ação de petróleo. Ambos os ativos mostram grandes flutuações, especialmente entre 2014 e 2016, com o Índice Bovespa apresentando mais variações abruptas do que a ação ajustada pela inflação. Em geral, o Índice Bovespa tende a ser mais estável, enquanto a ação de petróleo reflete de maneira mais intensa as mudanças econômicas e políticas no Brasil.

# %%
df_mean[['taxa_real_acao','taxa_real_ibovespa']]
# Out:
#      taxa_real_acao  taxa_real_ibovespa
# 0               NaN                 NaN
# 1         -6.712565            0.927251
# 2         14.603500            4.216059
# 3        -19.551862           -5.978739
# 4         -6.417894          -10.631420
# ..              ...                 ...
# 175       -5.340190            1.956693
# 176       -3.263568           -7.019160
# 177      -10.697940           -5.765132
# 178        7.222539           -7.519132
# 179       -9.785530           -8.732146
#
# [180 rows x 2 columns]

# %%
df_teste = df_mean.copy()

# %%
df_teste['Normalized_EYAC2'] = df_teste['Close_Real_EYAC2'] / df_teste['Close_Real_EYAC2'].iloc[0]
df_teste['Normalized_Ibovespa'] = df_teste['Índice_Ibovespa'] / df_teste['Índice_Ibovespa'].iloc[0]

# %%
# Gráfico de Normalização
plt.figure(figsize=(14, 7))
plt.plot(df_teste['Date'], df_teste['Normalized_EYAC2'], label='Close_Real_EYAC2 Normalizado', color='blue')
plt.plot(df_teste['Date'], df_teste['Normalized_Ibovespa'], label='Índice Ibovespa Normalizado', color='red')
plt.title('Comparação Normalizada entre Ação em Real e Índice Ibovespa')
plt.xlabel('Date')
plt.ylabel('Valor Normalizado')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Fig30:.O gráfico mostra a comparação entre o desempenho da Ação em Real e o Índice Bovespa ao longo do período de 2010 a 2024, com ambos os indicadores normalizados para análise de seu crescimento relativo. A Ação em Real teve um crescimento mais volátil e lento, especialmente no início do período, enquanto o Índice Bovespa teve um desempenho mais consistente e acentuado, principalmente após 2020. O Índice Bovespa superou a Ação em Real em termos de valorização relativa, especialmente devido ao crescimento robusto após 2020, enquanto a Ação em Real apresentou flutuações mais amplas e crescimento mais moderado.

# %% [markdown]
# Sazonalidade

# %%
df2 = df1.copy()

# %%
df2['Mês'] = df2.Date.dt.month

# %%
df2['Ano'] = df2.Date.dt.year

# %%
pivot = df2.pivot_table(index='Mês', columns='Ano', values='Close_Real_EYAC2')

# %%
pivot.head()
# Out:
# Ano       2010       2011       2012       2013       2014       2015  \
# Mês
# 1    33.935703  28.561427  22.090243  18.034978  14.965455   7.985905
# 2    31.895180  26.910166  22.250865  18.480333  14.010863   9.318587
# 3    37.114391  29.877908  25.985871  15.954865  18.342314   9.685616
# 4    30.474053  22.202078  19.012198  20.112891  15.405017  12.587538
# 5    29.272740  25.165551  17.353490  16.429340  14.828711  13.067128
#
# Ano      2016       2017       2018       2019       2020       2021  \
# Mês
# 1    7.815621  16.772941  18.954783  26.151811  24.470724  24.492515
# 2    5.748161  14.275585  22.104604  26.013430  23.568969  21.818041
# 3    7.353476  17.157792  20.186798  27.985957  15.424223  25.591074
# 4    9.190977  15.636543  24.098236  26.053660  18.733976  22.095336
# 5    6.592826  14.114903  18.799722  25.502077  22.170792  28.453772
#
# Ano       2022       2023       2024
# Mês
# 1    30.649286  26.817522  38.632532
# ...

# %%
plt.figure(figsize=(10, 6))
for year in pivot.columns:
    plt.plot(pivot.index, pivot[year], label=year)

plt.xlabel('Mês')
plt.ylabel('Valor da ação')
plt.title('Sazonalidade Mensal da Ação em Real')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45) 
plt.tight_layout() 
plt.show()

# %%
pivot2 = df2.pivot_table(index='Mês', columns='Ano', values='Price_Dolar_Petro')

# %%
plt.figure(figsize=(10, 6))
for year in pivot2.columns:
    plt.plot(pivot2.index, pivot2[year], label=year)

plt.xlabel('Mês')
plt.ylabel('Valor da ação')
plt.title('Sazonalidade Mensal do Barril do Petróleo em dólar')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45) 
plt.tight_layout() 
plt.show()

# %%
pivot3 = df2.pivot_table(index='Mês', columns='Ano', values='Close_Dolar_EYAC2')

# %%
plt.figure(figsize=(10, 6))
for year in pivot3.columns:
    plt.plot(pivot3.index, pivot3[year], label=year)

plt.xlabel('Mês')
plt.ylabel('Valor da ação')
plt.title('Sazonalidade Mensal da Ação em Dólar')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45) 
plt.tight_layout() 
plt.show()

# %%
pivot4 = df2.pivot_table(index='Mês', columns='Ano', values='Índice_Ibovespa')

# %%
plt.figure(figsize=(10, 6))
for year in pivot4.columns:
    plt.plot(pivot4.index, pivot4[year], label=year)

plt.xlabel('Mês')
plt.ylabel('Valor da ação')
plt.title('Sazonalidade Mensal do Índice do Ibovespa')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45) 
plt.tight_layout() 
plt.show()

# %%
#Número de anos para plotar
anos = range(2010, 2025)
num_anos = len(anos)

#Criando subplots com 2 colunas
n_cols = 2
n_rows = (num_anos + n_cols - 1) // n_cols

fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, 10))

#Loop para plotar os dados
for i, year in enumerate(anos):
    row = i // n_cols  #Linha
    col = i % n_cols   #Coluna
    axs[row, col].plot(pivot.index, pivot[year], label=year)
    axs[row, col].set_title(str(year), fontsize=14)

#Desativa o eixo do subplot 
for j in range(num_anos, n_rows * n_cols):
    axs[j // n_cols, j % n_cols].axis('off')     


plt.suptitle("Sazonalidade mensal da ação em Real", fontsize=20, y=1.5)
plt.tight_layout(rect=[0, 0, 1,1.5])
plt.show()
